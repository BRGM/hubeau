# %%
import pandas as pd
import json
import unicodedata
import numpy as np
import requests
import re
from SPARQLWrapper import SPARQLWrapper2

# %%
df=pd.read_csv("Data/commune2021.csv")
communes_ = np.array(df["LIBELLE"])
communes_
# Out:
# array(["L'Abergement-Clémenciat", "L'Abergement-de-Varey",
#        'Ambérieu-en-Bugey', ..., 'Pamandzi', 'Sada', 'Tsingoni'],
#       dtype=object)

# %%
communes, counts = np.unique(communes_, return_counts=True)

# %%
len(communes), len(communes_)
# Out:
# (35084, 37742)

# %%
def get_insee(commune):
    """
    returns the insee code of the commune
    """
    commune_ = unicodedata.normalize('NFD', commune.lower()).encode('ascii', 'ignore').decode("utf-8")
    url = 'https://geo.api.gouv.fr/communes?nom={c}&fields=nom,code,codesPostaux,'\
              'codeDepartement,codeRegion,population&format=json&geometry=centre'\
              .format(c=commune_)
    exists = len(json.loads(requests.get(url).text))
    if exists>0 :
        codes = json.loads(requests.get(url).text)
        result = [code["code"] for code in codes \
                if  unicodedata.normalize('NFD', code["nom"].lower()).encode('ascii', 'ignore').decode("utf-8") == commune_]
        if len(result)>0:
            return result
        return -1
    return -1

# %%
def dbPedia_get_gentile(insee):
    """
    Returns the dbo:peopleName property of the commune corresponding to the insee code
    """
    
    d = SPARQLWrapper2("http://fr.dbpedia.org/sparql")

    d.setQuery(
    """
    PREFIX dbo: <http://dbpedia.org/ontology/>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>

    SELECT distinct ?ville ?gentile
    WHERE
    {
      # ?ville dbo:peopleName  ?gentile.
      # ?ville dbo:country  <http://fr.dbpedia.org/resource/France>.
      # ?ville dbo:inseeCode ?insee.
      filter(regex(?insee,\"^""" +insee+ """\", "i"))
    }
      """
    ) 
    communes = set()
    res = d.query().bindings
    for result in res:
        communes.add(unicodedata.normalize('NFD', result["gentile"].value.lower()).encode('ascii', 'ignore').decode("utf-8"))
        
    return communes

# %% [markdown]
# ### For each commune, extract from dbPedia the dbo:peopleName property if it exists

# %%
# gentiles = {}
# for commune in communes:
#     print(commune)
#     insee = get_insee(commune)
#     if insee != -1: 
#         result = set()
#         for insee_ in insee:
#             g = dbPedia_get_gentile(insee_)
#             result  = result.union(g)
        
#         if(len(result)>0):
#             gentiles[commune] = list(result)
        
#         print(commune, result)
#         print("____________________________________________________")  
        
# with open("Data/dbPedia_extracted_demonyms2.json", "w") as fp:
#     json.dump(gentiles,fp)

# %% [markdown]
# ### Preprocess extracted text

# %%
from nltk.stem.snowball import FrenchStemmer
stemmer = FrenchStemmer()

gentiles_ = {}
for com in gentiles:
    list_g = gentiles[com]
    result = set()
    for g in list_g:
        g1 = re.sub("\(.*\)", "", g)
        g2 = re.sub("\sou\s|\set\s|;|/", ",", g1)
        print(g2)
        split_g = re.split("\s?,,?\s?", g2)
        print(split_g)
        for split_g_ in split_g:  
            result.add(split_g_)
    result = list(result)
    gentiles_[com] = result   
    print(com, list_g, result)
# Out:
# aastais
# ['aastais']
# Aast ['aastais'] ['aastais']
# abainvillois
# ['abainvillois']
# Abainville ['abainvillois'] ['abainvillois']
# abancourtois
# ['abancourtois']
# Abancourt ['abancourtois'] ['abancourtois']
# abaucourtois
# ['abaucourtois']
# Abaucourt-Hautecourt ['abaucourtois'] ['abaucourtois']
# abbarois
# ['abbarois']
# Abbaretz ['abbarois'] ['abbarois']
# abbecourtois
# ['abbecourtois']
# Abbecourt ['abbecourtois'] ['abbecourtois']
# abbenanais
# ['abbenanais']
# Abbenans ['abbenanais'] ['abbenanais']
# abbevillois
# ['abbevillois']
# Abbeville ['abbevillois(e)'] ['abbevillois']
# abbevillois
# ['abbevillois']
# Abbeville-Saint-Lucien ['abbevillois'] ['abbevillois']
# abbecourtois
# ['abbecourtois']
# Abbécourt ['abbecourtois'] ['abbecourtois']
# abbevillois
# ['abbevillois']
# Abbéville-la-Rivière ['abbevillois'] ['abbevillois']
# abeilhanais
# ['abeilhanais']
# Abeilhan ['abeilhanais'] ['abeilhanais']
# abergeois
# ['abergeois']
# Abergement-la-Ronce ['abergeois'] ['abergeois']
# abergementiers, abergementieres
# ['abergementiers', 'abergementieres']
# Abergement-le-Petit ['abergementiers, abergementieres'] ['abergementiers', 'abergementieres']
# abillois
# ['abillois']
# Abilly ['abillois'] ['abillois']
# abitainois
# ['abitainois']
# Abitain ['abitainois'] ['abitainois']
# abjacois
# ['abjacois']
# Abjat-sur-Bandiat ['abjacois'] ['abjacois']
# ablainois
# ['ablainois']
# Ablain-Saint-Nazaire ['ablainois'] ['ablainois']
# ablainzevellois
# ['ablainzevellois']
# Ablainzevelle ['ablainzevellois'] ['ablainzevellois']
# blancourtien
# ['blancourtien']
# Ablancourt ['blancourtien'] ['blancourtien']
# ableigeois
# ['ableigeois']
# Ableiges ['ableigeois'] ['ableigeois']
# ablisiens
# ['ablisiens']
# Ablis ['ablisiens'] ['ablisiens']
# ablonnais
# ['ablonnais']
# Ablon ['ablonnais'] ['ablonnais']
# ablonais
# ['ablonais']
# Ablon-sur-Seine ['ablonais'] ['ablonais']
# abondancieres , abondanciers
# ['abondancieres', 'abondanciers']
# Abondance ['abondancieres / abondanciers'] ['abondanciers', 'abondancieres']
# abondantais
# ['abondantais']
# Abondant ['abondantais(e)'] ['abondantais']
# abosien
# ['abosien']
# Abos ['abosien'] ['abosien']
# abrienais
# ['abrienais']
# Aboën ['abrienais'] ['abrienais']
# abrestois
# ['abrestois']
# Abrest ['abrestois'] ['abrestois']
# absconnais
# ['absconnais']
# Abscon ['absconnais'] ['absconnais']
# abzacais
# ['abzacais']
# abzacois,abzacais
# ['abzacois', 'abzacais']
# Abzac ['abzacais', 'abzacois ou abzacais'] ['abzacais', 'abzacois']
# acconnais, acconnaises
# ['acconnais', 'acconnaises']
# Accons ['acconnais, acconnaises'] ['acconnais', 'acconnaises']
# achenois
# ['achenois']
# Achen ['achenois'] ['achenois']
# achenheimois
# ['achenheimois']
# Achenheim ['achenheimois(es)'] ['achenheimois']
# acheryens
# ['acheryens']
# Achery ['acheryens'] ['acheryens']
# acheen
# ['acheen']
# Acheux-en-Amiénois ['acheen(ne)(s)'] ['acheen']
# achicouriens,achicourtois
# ['achicouriens', 'achicourtois']
# Achicourt ['achicouriens ou achicourtois'] ['achicouriens', 'achicourtois']
# achunois, achunoises
# ['achunois', 'achunoises']
# Achun ['achunois, achunoises'] ['achunois', 'achunoises']
# acherois
# ['acherois']
# Achères ['acherois'] ['acherois']
# acherois
# ['acherois']
# Achères-la-Forêt ['acherois'] ['acherois']
# acignolais
# ['acignolais']
# Acigné ['acignolais'] ['acignolais']
# aclouais, aclouaise
# ['aclouais', 'aclouaise']
# Aclou ['aclouais, aclouaise'] ['aclouaise', 'aclouais']
# acconais
# ['acconais']
# Acon ['acconais'] ['acconais']
# acquignicien, acquignicienne
# ['acquignicien', 'acquignicienne']
# Acquigny ['acquignicien, acquignicienne'] ['acquignicien', 'acquignicienne']
# aceens
# ['aceens']
# Acy-en-Multien ['aceens'] ['aceens']
# adainvillois
# ['adainvillois']
# Adainville ['adainvillois'] ['adainvillois']
# adamswillerois
# ['adamswillerois']
# Adamswiller ['adamswillerois(se)'] ['adamswillerois']
# adastois, adastoises
# ['adastois', 'adastoises']
# Adast ['adastois, adastoises'] ['adastoises', 'adastois']
# aderguois, aderguoises
# ['aderguois', 'aderguoises']
# Adervielle-Pouchergues ['aderguois, aderguoises'] ['aderguois', 'aderguoises']
# adillysiens
# ['adillysiens']
# Adilly ['adillysiens'] ['adillysiens']
# adinferois
# ['adinferois']
# Adinfer ['adinferois'] ['adinferois']
# adonnais
# ['adonnais']
# Adon ['adonnais'] ['adonnais']
# adriauds
# ['adriauds']
# Adriers ['adriauds'] ['adriauds']
# adeens, adeennes
# ['adeens', 'adeennes']
# Adé ['adeens, adeennes'] ['adeennes', 'adeens']
# afaghjinchi
# ['afaghjinchi']
# afayens
# ['afayens']
# Afa ['afaghjinchi', 'afayens'] ['afaghjinchi', 'afayens']
# afflevillois
# ['afflevillois']
# Affléville ['afflevillois'] ['afflevillois']
# affousiens
# ['affousiens']
# Affoux ['affousiens'] ['affousiens']
# affracurtiens
# ['affracurtiens']
# Affracourt ['affracurtiens'] ['affracurtiens']
# agassacois, agassacoises
# ['agassacois', 'agassacoises']
# Agassac ['agassacois, agassacoises'] ['agassacois', 'agassacoises']
# agathois, agathoise
# ['agathois', 'agathoise']
# Agde ['agathois, agathoise'] ['agathoise', 'agathois']
# agelois
# ['agelois']
# Agel ['agelois'] ['agelois']
# agenais
# ['agenais']
# Agen ['agenais'] ['agenais']
# agentols
# ['agentols']
# Agen-d'Aveyron ['agentols'] ['agentols']
# agenvillois,agenvillerois
# ['agenvillois', 'agenvillerois']
# Agenvillers ['agenvillois ou agenvillerois'] ['agenvillerois', 'agenvillois']
# aghionais
# ['aghionais']
# Aghione ['aghionais'] ['aghionais']
# agmeennes
# ['agmeennes']
# agmeens
# ['agmeens']
# Agmé ['agmeennes', 'agmeens'] ['agmeennes', 'agmeens']
# agnacoises
# ['agnacoises']
# agnacois
# ['agnacois']
# Agnac ['agnacoises', 'agnacois'] ['agnacoises', 'agnacois']
# agnelais
# ['agnelais']
# Agneaux ['agnelais'] ['agnelais']
# agnessois
# ['agnessois']
# Agnetz ['agnessois'] ['agnessois']
# agnosien
# ['agnosien']
# Agnos ['agnosien'] ['agnosien']
# agnynois
# ['agnynois']
# Agny ['agnynois'] ['agnynois']
# agonais-coutainvillais
# ['agonais-coutainvillais']
# Agon-Coutainville ['agonais-coutainvillais'] ['agonais-coutainvillais']
# agonacois
# ['agonacois']
# Agonac ['agonacois(es)'] ['agonacois']
# agonesois
# ['agonesois']
# Agonès ['agonesois'] ['agonesois']
# agolosiens, agolosiennes
# ['agolosiens', 'agolosiennes']
# Agos-Vidalos ['agolosiens, agolosiennes'] ['agolosiennes', 'agolosiens']
# agritois, agritauds
# ['agritois', 'agritauds']
# Agris ['agritois, agritauds'] ['agritois', 'agritauds']
# agudellois
# ['agudellois']
# Agudelle ['agudellois'] ['agudellois']
# nagassols
# ['nagassols']
# Aguessac ['nagassols'] ['nagassols']
# agussiens
# ['agussiens']
# Aguts ['agussiens'] ['agussiens']
# ahatsar
# ['ahatsar']
# Ahaxe-Alciette-Bascassan ['ahatsar'] ['ahatsar']
# aheztar
# ['aheztar']
# Ahetze ['aheztar'] ['aheztar']
# ahuilleen
# ['ahuilleen']
# Ahuillé ['ahuilleen'] ['ahuilleen']
# ahunois
# ['ahunois']
# Ahun ['ahunois'] ['ahunois']
# ahevillois
# ['ahevillois']
# Ahéville ['ahevillois'] ['ahevillois']
# aibois
# ['aibois']
# Aibes ['aibois'] ['aibois']
# aiffricains, aiffricaines
# ['aiffricains', 'aiffricaines']
# Aiffres ['aiffricains, aiffricaines'] ['aiffricaines', 'aiffricains']
# aiglevillois, aiglevilloise
# ['aiglevillois', 'aiglevilloise']
# Aigleville ['aiglevillois, aiglevilloise'] ['aiglevilloise', 'aiglevillois']
# aiglenois
# ['aiglenois']
# Aiglun ['aiglenois'] ['aiglenois']
# aignanais, aignanaise
# ['aignanais', 'aignanaise']
# Aignan ['aignanais, aignanaise'] ['aignanais', 'aignanaise']
# aigneen
# ['aigneen']
# Aigne ['aigneen'] ['aigneen']
# aignois, aignoises
# ['aignois', 'aignoises']
# Aignes ['aignois, aignoises'] ['aignoises', 'aignois']
# aignevillois
# ['aignevillois']
# Aigneville ['aignevillois'] ['aignevillois']
# aquanidien
# ['aquanidien']
# Aigny ['aquanidien'] ['aquanidien']
# aigneen
# ['aigneen']
# Aigné ['aigneen'] ['aigneen']
# mougonais, mougonaises
# ['mougonais', 'mougonaises']
# Aigondigné ['mougonais, mougonaises'] ['mougonais', 'mougonaises']
# aigrinois
# ['aigrinois']
# Aigre ['aigrinois'] ['aigrinois']
# aigrefeuillois
# ['aigrefeuillois']
# Aigrefeuille ['aigrefeuillois'] ['aigrefeuillois']
# aigrefeuillais
# ['aigrefeuillais']
# Aigrefeuille-d'Aunis ['aigrefeuillais'] ['aigrefeuillais']
# agrifoliens
# ['agrifoliens']
# aigrefeuillais
# ['aigrefeuillais']
# Aigrefeuille-sur-Maine ['agrifoliens', 'aigrefeuillais'] ['agrifoliens', 'aigrefeuillais']
# aigremontois, aigremontoises
# ['aigremontois', 'aigremontoises']
# Aigremont ['aigremontois, aigremontoises'] ['aigremontoises', 'aigremontois']
# aiguebelletois,,gabelans,gabelannes
# ['aiguebelletois', 'gabelans', 'gabelannes']
# Aiguebelette-le-Lac ['aiguebelletois, ou gabelans et gabelannes'] ['aiguebelletois', 'gabelannes', 'gabelans']
# aiguefondais
# ['aiguefondais ']
# Aiguefonde ['aiguefondais (en occitan, aigafondeses)'] ['aiguefondais ']
# aiguepersirons
# ['aiguepersirons']
# Aigueperse ['aiguepersirons'] ['aiguepersirons']
# aigues-juntais
# ['aigues-juntais']
# Aigues-Juntes ['aigues-juntais'] ['aigues-juntais']
# aigues-mortais, aigues-mortaise
# ['aigues-mortais', 'aigues-mortaise']
# Aigues-Mortes ['aigues-mortais, aigues-mortaise'] ['aigues-mortaise', 'aigues-mortais']
# aiguesvivois
# ['aiguesvivois']
# aigues-viveviens
# ['aigues-viveviens']
# aigues-vivois, aigues-vivoise
# ['aigues-vivois', 'aigues-vivoise']
# Aigues-Vives ['aiguesvivois', 'aigues-viveviens', 'aigues-vivois, aigues-vivoise'] ['aigues-viveviens', 'aiguesvivois', 'aigues-vivois', 'aigues-vivoise']
# aiguillonaises
# ['aiguillonaises']
# aiguillonais
# ['aiguillonais']
# Aiguillon ['aiguillonaises', 'aiguillonais'] ['aiguillonaises', 'aiguillonais']
# aiguinois, aiguinoises
# ['aiguinois', 'aiguinoises']
# Aiguines ['aiguinois, aiguinoises'] ['aiguinois', 'aiguinoises']
# aigurandais
# ['aigurandais']
# Aigurande ['aigurandais'] ['aigurandais']
# aiguezois
# ['aiguezois']
# Aiguèze ['aiguezois'] ['aiguezois']
# aillantais
# ['aillantais']
# Aillant-sur-Milleron ['aillantais'] ['aillantais']
# aillassais
# ['aillassais']
# Aillas ['aillassais'] ['aillassais']
# ailleutain
# ['ailleutain']
# Ailleux ['ailleutain'] ['ailleutain']
# aliacois,aliaciens
# ['aliacois', 'aliaciens']
# Ailly-le-Haut-Clocher ['aliacois ou aliaciens'] ['aliaciens', 'aliacois']
# aimarguois
# ['aimarguois']
# Aimargues ['aimarguois'] ['aimarguois']
# aimerains, aimeraines
# ['aimerains', 'aimeraines']
# Aime-la-Plagne ['aimerains, aimeraines'] ['aimerains', 'aimeraines']
# castelainaisiens
# ['castelainaisiens']
# Ainay-le-Château ['castelainaisiens'] ['castelainaisiens']
# aintzildar
# ['aintzildar']
# Aincille ['aintzildar'] ['aintzildar']
# aincourtois, aincourtoises
# ['aincourtois', 'aincourtoises']
# Aincourt ['aincourtois, aincourtoises'] ['aincourtois', 'aincourtoises']
# aingevillois
# ['aingevillois']
# Aingeville ['aingevillois(es)'] ['aingevillois']
# ainharbear
# ['ainharbear']
# Ainharp ['ainharbear'] ['ainharbear']
# ainhiztar
# ['ainhiztar']
# Ainhice-Mongelos ['ainhiztar'] ['ainhiztar']
# ainhoar
# ['ainhoar']
# Ainhoa ['ainhoar'] ['ainhoar']
# ainvellois
# ['ainvellois']
# Ainvelle ['ainvellois(es)'] ['ainvellois']
# airainois
# ['airainois']
# Airaines ['airainois(e)(s)'] ['airainois']
# aturins
# ['aturins']
# Aire-sur-l'Adour ['aturins'] ['aturins']
# airois
# ['airois']
# Aire-sur-la-Lys ['airois'] ['airois']
# airionnais
# ['airionnais']
# Airion ['airionnais'] ['airionnais']
# aironnois
# ['aironnois']
# Airon-Notre-Dame ['aironnois'] ['aironnois']
# airouxois
# ['airouxois']
# Airoux ['airouxois'] ['airouxois']
# airvaudais
# ['airvaudais']
# Airvault ['airvaudais'] ['airvaudais']
# aitinchi
# ['aitinchi']
# Aiti ['aitinchi'] ['aitinchi']
# aixois
# ['aixois']
# Aix ['aixois'] ['aixois']
# aixois
# ['aixois']
# Aix-Noulette ['aixois'] ['aixois']
# aixois
# ['aixois']
# Aix-en-Ergny ['aixois'] ['aixois']
# aixois,aquisextains
# ['aixois', 'aquisextains']
# Aix-en-Provence ['aixois ou aquisextains'] ['aquisextains', 'aixois']
# aixois
# ['aixois']
# Aix-les-Bains ['aixois'] ['aixois']
# aixois
# ['aixois']
# Aixe-sur-Vienne ['aixois'] ['aixois']
# agesinate
# ['agesinate']
# agerinate
# ['agerinate']
# agezynate
# ['agezynate']
# Aizenay ['agesinate', 'agerinate', 'agezynate'] ['agerinate', 'agesinate', 'agezynate']
# aizierois
# ['aizierois']
# Aizier ['aizierois'] ['aizierois']
# aiaccini
# ['aiaccini']
# ajacciens
# ['ajacciens']
# Ajaccio ['aiaccini', 'ajacciens'] ['aiaccini', 'ajacciens']
# ajacois
# ['ajacois']
# Ajat ['ajacois'] ['ajacois']
# ajouxois, ajouxoises
# ['ajouxois', 'ajouxoises']
# Ajoux ['ajouxois, ajouxoises'] ['ajouxois', 'ajouxoises']
# alairacoises, alairacois
# ['alairacoises', 'alairacois']
# Alairac ['alairacoises, alairacois'] ['alairacois', 'alairacoises']
# alanais
# ['alanais']
# Alan ['alanais'] ['alanais']
# alandesi
# ['alandesi']
# alandais
# ['alandais']
# Alando ['alandesi', 'alandais'] ['alandesi', 'alandais']
# albains, albaines
# ['albains', 'albaines']
# Alba-la-Romaine ['albains, albaines'] ['albains', 'albaines']
# albanais
# ['albanais']
# Alban ['albanais'] ['albanais']
# albaretais
# ['albaretais']
# Albaret-Sainte-Marie ['albaretais'] ['albaretais']
# albassiens, albassiennes
# ['albassiens', 'albassiennes']
# Albas ['albassiens, albassiennes'] ['albassiens', 'albassiennes']
# albertins, albertines
# ['albertins', 'albertines']
# Albert ['albertins, albertines'] ['albertines', 'albertins']
# albertvillois , albertvilloises
# ['albertvillois', 'albertvilloises']
# Albertville ['albertvillois / albertvilloises'] ['albertvillois', 'albertvilloises']
# albigeoises, albigeois
# ['albigeoises', 'albigeois']
# Albi ['albigeoises, albigeois'] ['albigeoises', 'albigeois']
# albiacois, albiacoises
# ['albiacois', 'albiacoises']
# Albiac ['albiacois, albiacoises'] ['albiacoises', 'albiacois']
# albiassains, albiassaines
# ['albiassains', 'albiassaines']
# Albias ['albiassains, albiassaines'] ['albiassaines', 'albiassains']
# albiens, albienches
# ['albiens', 'albienches']
# Albiez-Montrond ['albiens, albienches'] ['albienches', 'albiens']
# albignolais
# ['albignolais']
# Albigny-sur-Saône ['albignolais'] ['albignolais']
# albinols
# ['albinols']
# Albine ['albinols'] ['albinols']
# albierois
# ['albierois']
# Albières ['albierois'] ['albierois']
# albonnais, albonnaises
# ['albonnais', 'albonnaises']
# Albon ['albonnais, albonnaises'] ['albonnaises', 'albonnais']
# albonnais
# ['albonnais']
# Albon-d'Ardèche ['albonnais'] ['albonnais']
# albygeois
# ['albygeois']
# Alby-sur-Chéran ['albygeois'] ['albygeois']
# albegeois
# ['albegeois']
# Albé ['albegeois(es)'] ['albegeois']
# aldudar
# ['aldudar']
# Aldudes ['aldudar'] ['aldudar']
# alenconnais
# ['alenconnais']
# Alençon ['alenconnais'] ['alenconnais']
# aletois
# ['aletois']
# Alet-les-Bains ['aletois'] ['aletois']
# aleusiens
# ['aleusiens']
# Aleu ['aleusiens'] ['aleusiens']
# alexinois
# ['alexinois']
# Alexain ['alexinois'] ['alexinois']
# aleyraciens
# ['aleyraciens']
# Aleyrac ['aleyraciens'] ['aleyraciens']
# alfortvillais
# ['alfortvillais']
# Alfortville ['alfortvillais'] ['alfortvillais']
# algajolais
# ['algajolais']
# algaghjulesi
# ['algaghjulesi']
# Algajola ['algajolais', 'algaghjulesi'] ['algajolais', 'algaghjulesi']
# algansois
# ['algansois']
# Algans ['algansois'] ['algansois']
# algolsheimoi
# ['algolsheimoi']
# Algolsheim ['algolsheimoi(se)'] ['algolsheimoi']
# alisien
# ['alisien']
# Alise-Sainte-Reine ['alisien'] ['alisien']
# alissains, alissaines
# ['alissains', 'alissaines']
# Alissas ['alissains, alissaines'] ['alissains', 'alissaines']
# alixois
# ['alixois']
# Alix ['alixois'] ['alixois']
# allainvillois
# ['allainvillois']
# Allainville ['allainvillois'] ['allainvillois']
# allairiens
# ['allairiens']
# Allaire ['allairiens'] ['allairiens']
# allamontois
# ['allamontois']
# Allamont ['allamontois'] ['allamontois']
# allanais
# ['allanais']
# Allan ['allanais'] ['allanais']
# hilarismontais
# ['hilarismontais']
# Allarmont ['hilarismontais'] ['hilarismontais']
# allasiens
# ['allasiens']
# Allas-Bocage ['allasiens'] ['allasiens']
# allasiens
# ['allasiens']
# Allas-Champagne ['allasiens'] ['allasiens']
# allacois
# ['allacois']
# Allas-les-Mines ['allacois'] ['allacois']
# allassacois
# ['allassacois']
# Allassac ['allassacois'] ['allassacois']
# allaudienne, allaudien
# ['allaudienne', 'allaudien']
# Allauch ['allaudienne, allaudien'] ['allaudienne', 'allaudien']
# alleinsois
# ['alleinsois']
# Alleins ['alleinsois'] ['alleinsois']
# allemagniens
# ['allemagniens']
# Allemagne-en-Provence ['allemagniens'] ['allemagniens']
# allemanchots, allemanchottes
# ['allemanchots', 'allemanchottes']
# Allemanche-Launay-et-Soyer ['allemanchots, allemanchottes'] ['allemanchots', 'allemanchottes']
# allemanais
# ['allemanais']
# allemanaises
# ['allemanaises']
# Allemans-du-Dropt ['allemanais', 'allemanaises'] ['allemanais', 'allemanaises']
# allamants, allamantes
# ['allamants', 'allamantes']
# Allemant ['allamants, allamantes'] ['allamantes', 'allamants']
# allemondins
# ['allemondins']
# Allemond ['allemondins'] ['allemondins']
# allenjoyeux
# ['allenjoyeux']
# Allenjoie ['allenjoyeux'] ['allenjoyeux']
# allennois
# ['allennois']
# Allennes-les-Marais ['allennois'] ['allennois']
# allevardins , allevardines
# ['allevardins', 'allevardines']
# Allevard ['allevardins / allevardines'] ['allevardins', 'allevardines']
# alleyracois, alleyracoises
# ['alleyracois', 'alleyracoises']
# Alleyrac ['alleyracois, alleyracoises'] ['alleyracois', 'alleyracoises']
# alleyratois
# ['alleyratois']
# Alleyrat ['alleyratois'] ['alleyratois']
# alleziennes
# ['alleziennes']
# alleziens
# ['alleziens']
# Allez-et-Cazeneuve ['alleziennes', 'alleziens'] ['alleziennes', 'alleziens']
# argencellier, argencelliere
# ['argencellier', 'argencelliere']
# Alliancelles ['argencellier et  argencelliere'] ['argencellier', 'argencelliere']
# alliatois
# ['alliatois']
# Alliat ['alliatois'] ['alliatois']
# allierois, allieroises
# ['allierois', 'allieroises']
# Allier ['allierois, allieroises'] ['allierois', 'allieroises']
# allineucois, allineucoise
# ['allineucois', 'allineucoise']
# Allineuc ['allineucois, allineucoise'] ['allineucoise', 'allineucois']
# allingeois , allingeoises
# ['allingeois', 'allingeoises']
# Allinges ['allingeois / allingeoises'] ['allingeois', 'allingeoises']
# allierasois
# ['allierasois']
# Allières ['allierasois'] ['allierasois']
# allognois
# ['allognois']
# Allogny ['allognois'] ['allognois']
# allondains
# ['allondains']
# Allondaz ['allondains'] ['allondains']
# allonnais
# ['allonnais']
# Allonne ['allonnais'] ['allonnais']
# allonnais
# ['allonnais']
# Allonnes ['allonnais'] ['allonnais']
# allonais
# ['allonais']
# allonsais
# ['allonsais']
# Allons ['allonais', 'allonsais'] ['allonais', 'allonsais']
# allonvillois
# ['allonvillois']
# allonvilloises
# ['allonvilloises']
# Allonville ['allonvillois', 'allonvilloises'] ['allonvillois', 'allonvilloises']
# allonzierains
# ['allonzierains']
# Allonzier-la-Caille ['allonzierains'] ['allonzierains']
# poulouches
# ['poulouches']
# Allouagne ['poulouches'] ['poulouches']
# allousiens
# ['allousiens']
# Alloue ['allousiens'] ['allousiens']
# allouvillais,allouvillaises
# ['allouvillais', 'allouvillaises']
# Allouville-Bellefosse ['allouvillais et allouvillaises'] ['allouvillais', 'allouvillaises']
# alluysiens, alluysiennes
# ['alluysiens', 'alluysiennes']
# Alluy ['alluysiens, alluysiennes'] ['alluysiennes', 'alluysiens']
# avallosiennes, avallosiens.
# ['avallosiennes', 'avallosiens.']
# Alluyes ['avallosiennes, avallosiens.'] ['avallosiennes', 'avallosiens.']
# allegrat, allegrate
# ['allegrat', 'allegrate']
# Allègre ['allegrat, allegrate'] ['allegrat', 'allegrate']
# allevains, allevaines
# ['allevains', 'allevaines']
# Allèves ['allevains, allevaines'] ['allevains', 'allevaines']
# mairacois
# ['mairacois']
# Almayrac ['mairacois'] ['mairacois']
# almenechois
# ['almenechois']
# Almenêches ['almenechois'] ['almenechois']
# almontois
# ['almontois']
# Almont-les-Junies ['almontois'] ['almontois']
# alosiens
# ['alosiens']
# alosois
# ['alosois']
# Alos ['alosiens', 'alosois'] ['alosiens', 'alosois']
# aloztar
# ['aloztar']
# Alos-Sibas-Abense ['aloztar'] ['aloztar']
# alrancais
# ['alrancais']
# Alrance ['alrancais'] ['alrancais']
# alstingeois,alstingeoise , zinzingeois,zinzingeoise
# ['alstingeois', 'alstingeoise', 'zinzingeois', 'zinzingeoise']
# Alsting ['alstingeois/alstingeoise ; zinzingeois/zinzingeoise'] ['alstingeois', 'alstingeoise', 'zinzingeois', 'zinzingeoise']
# altaghjinesi
# ['altaghjinesi']
# altagenais
# ['altagenais']
# Altagène ['altaghjinesi', 'altagenais'] ['altaghjinesi', 'altagenais']
# alteckendorfois
# ['alteckendorfois']
# Alteckendorf ['alteckendorfois'] ['alteckendorfois']
# dannemariens
# ['dannemariens']
# Altenach ['dannemariens'] ['dannemariens']
# altenheimois, altenheimoises
# ['altenheimois', 'altenheimoises']
# Altenheim ['altenheimois, altenheimoises'] ['altenheimois', 'altenheimoises']
# althenois, althenoises
# ['althenois', 'althenoises']
# Althen-des-Paluds ['althenois, althenoises'] ['althenois', 'althenoises']
# altianinchi
# ['altianinchi']
# altianais
# ['altianais']
# Altiani ['altianinchi', 'altianais'] ['altianinchi', 'altianais']
# altierois
# ['altierois']
# Altier ['altierois'] ['altierois']
# altkirchois, altkirchoises
# ['altkirchois', 'altkirchoises']
# Altkirch ['altkirchois, altkirchoises'] ['altkirchoises', 'altkirchois']
# altorfois
# ['altorfois']
# Altorf ['altorfois'] ['altorfois']
# altwillerois, altwilleroises
# ['altwillerois', 'altwilleroises']
# Altwiller ['altwillerois, altwilleroises'] ['altwillerois', 'altwilleroises']
# alvimarais
# ['alvimarais']
# Alvimare ['alvimarais'] ['alvimarais']
# altzaiar
# ['altzaiar']
# Alçay-Alçabéhéty-Sunharette ['altzaiar'] ['altzaiar']
# alesiens, alesiennes
# ['alesiens', 'alesiennes']
# Alès ['alesiens, alesiennes'] ['alesiens', 'alesiennes']
# alenyanais, alenyanaises
# ['alenyanais', 'alenyanaises']
# Alénya ['alenyanais, alenyanaises'] ['alenyanaises', 'alenyanais']
# aleriacci, alerini
# ['aleriacci', 'alerini']
# aleriens
# ['aleriens']
# Aléria ['aleriacci, alerini', 'aleriens'] ['aleriacci', 'alerini', 'aleriens']
# amaliens, amalliens
# ['amaliens', 'amalliens']
# Amailloux ['amaliens, amalliens'] ['amalliens', 'amaliens']
# amanciens
# ['amanciens']
# Amancy ['amanciens'] ['amanciens']
# amangeois
# ['amangeois']
# Amange ['amangeois'] ['amangeois']
# amanlissien
# ['amanlissien']
# Amanlis ['amanlissien'] ['amanlissien']
# amanvillois
# ['amanvillois']
# Amanvillers ['amanvillois'] ['amanvillois']
# yaudes
# ['yaudes']
# Amanzé ['yaudes'] ['yaudes']
# amarensois
# ['amarensois']
# Amarens ['amarensois'] ['amarensois']
# amayens
# ['amayens']
# Amayé-sur-Seulles ['amayens'] ['amayens']
# ambacurtiens
# ['ambacurtiens']
# Ambacourt ['ambacurtien(ne)s'] ['ambacurtiens']
# ambaresiens
# ['ambaresiens']
# Ambarès-et-Lagrave ['ambaresiens'] ['ambaresiens']
# ambaxois
# ['ambaxois']
# Ambax ['ambaxois'] ['ambaxois']
# ambazacois
# ['ambazacois']
# Ambazac ['ambazacois'] ['ambazacois']
# ambellons
# ['ambellons']
# Ambel ['ambellons'] ['ambellons']
# ambernacois
# ['ambernacois']
# Ambernac ['ambernacois'] ['ambernacois']
# amberrois
# ['amberrois']
# Amberre ['amberrois'] ['amberrois']
# ambairacois
# ['ambairacois']
# Ambeyrac ['ambairacois'] ['ambairacois']
# ambialetois
# ['ambialetois']
# Ambialet ['ambialetois'] ['ambialetois']
# ambierlois
# ['ambierlois']
# Ambierle ['ambierlois'] ['ambierlois']
# ambellousiens
# ['ambellousiens']
# Ambillou ['ambellousiens'] ['ambellousiens']
# ambilliens , ambilliennes
# ['ambilliens', 'ambilliennes']
# Ambilly ['ambilliens / ambilliennes'] ['ambilliens', 'ambilliennes']
# amblainvillois
# ['amblainvillois']
# Amblainville ['amblainvillois'] ['amblainvillois']
# ambleteusois
# ['ambleteusois']
# Ambleteuse ['ambleteusois'] ['ambleteusois']
# amblevillois
# ['amblevillois']
# Ambleville ['amblevillois'] ['amblevillois']
# amboisiens,ambaciens
# ['amboisiens', 'ambaciens']
# Amboise ['amboisiens ou ambaciens'] ['ambaciens', 'amboisiens']
# ambonnais, ambonnaise
# ['ambonnais', 'ambonnaise']
# Ambon ['ambonnais, ambonnaise'] ['ambonnaise', 'ambonnais']
# ambonnageen
# ['ambonnageen']
# Ambonnay ['ambonnageen'] ['ambonnageen']
# ambrais
# ['ambrais']
# Ambres ['ambrais'] ['ambrais']
# amboriverain
# ['amboriverain']
# Ambrières-les-Vallées ['amboriverain'] ['amboriverain']
# ambrunois
# ['ambrunois']
# Ambronay ['ambrunois'] ['ambrunois']
# ambrumesnilais
# ['ambrumesnilais']
# Ambrumesnil ['ambrumesnilais'] ['ambrumesnilais']
# ambrusiennes
# ['ambrusiennes']
# ambrusiens
# ['ambrusiens']
# Ambrus ['ambrusiennes', 'ambrusiens'] ['ambrusiennes', 'ambrusiens']
# ambesiens
# ['ambesiens']
# Ambès ['ambesiens'] ['ambesiens']
# amberacois
# ['amberacois']
# Ambérac ['amberacois'] ['amberacois']
# ambarrois
# ['ambarrois']
# Ambérieu-en-Bugey ['ambarrois'] ['ambarrois']
# ambarrois, ambarroises
# ['ambarrois', 'ambarroises']
# Ambérieux ['ambarrois, ambarroises'] ['ambarrois', 'ambarroises']
# amenduztar
# ['amenduztar']
# Amendeuix-Oneix ['amenduztar'] ['amenduztar']
# amenucourtais
# ['amenucourtais']
# Amenucourt ['amenucourtais'] ['amenucourtais']
# amfrevillais, amfrevillaises
# ['amfrevillais', 'amfrevillaises']
# Amfreville-Saint-Amand ['amfrevillais, amfrevillaises'] ['amfrevillais', 'amfrevillaises']
# amfrevillais, amfrevillaises
# ['amfrevillais', 'amfrevillaises']
# Amfreville-la-Mi-Voie ['amfrevillais, amfrevillaises'] ['amfrevillais', 'amfrevillaises']
# amienois
# ['amienois']
# Amiens ['amienois'] ['amienois']
# amillissiens
# ['amillissiens']
# Amillis ['amillissiens'] ['amillissiens']
# amillien
# ['amillien']
# amillois
# ['amillois']
# Amilly ['amillien(ne)', 'amillois'] ['amillois', 'amillien']
# amiratois
# ['amiratois']
# Amirat ['amiratois'] ['amiratois']
# ammerschwihriens, ammerschwihriennes
# ['ammerschwihriens', 'ammerschwihriennes']
# Ammerschwihr ['ammerschwihriens, ammerschwihriennes'] ['ammerschwihriens', 'ammerschwihriennes']
# amnevillois
# ['amnevillois']
# Amnéville ['amnevillois'] ['amnevillois']
# amoroztar
# ['amoroztar']
# Amorots-Succos ['amoroztar'] ['amoroztar']
# amplepuisiens
# ['amplepuisiens']
# Amplepuis ['amplepuisiens'] ['amplepuisiens']
# amplioises,ampliois
# ['amplioises', 'ampliois']
# Amplier ['amplioises et ampliois'] ['amplioises', 'ampliois']
# amprianinchi
# ['amprianinchi']
# Ampriani ['amprianinchi'] ['amprianinchi']
# ampuisaits
# ['ampuisaits']
# Ampuis ['ampuisaits'] ['ampuisaits']
# ampusiens
# ['ampusiens']
# Ampus ['ampusiens'] ['ampusiens']
# amureens, amureennes
# ['amureens', 'amureennes']
# Amuré ['amureens, amureennes'] ['amureennes', 'amureens']
# amedeens
# ['amedeens']
# Amy ['amedeens'] ['amedeens']
# ameliens, ameliennes,palaldeens, palaldeennes
# ['ameliens', 'ameliennes', 'palaldeens', 'palaldeennes']
# Amélie-les-Bains-Palalda ['ameliens, ameliennes et palaldeens, palaldeennes'] ['palaldeennes', 'ameliens', 'palaldeens', 'ameliennes']
# anaisiens
# ['anaisiens']
# Anais ['anaisiens'] ['anaisiens']
# ananais
# ['ananais']
# Anan ['ananais'] ['ananais']
# ancellus
# ['ancellus']
# Ancelle ['ancellus'] ['ancellus']
# ancemontois
# ['ancemontois']
# Ancemont ['ancemontois'] ['ancemontois']
# anceniens
# ['anceniens']
# Ancenis-Saint-Géréon ['anceniens'] ['anceniens']
# ancervillois
# ['ancervillois']
# Ancerville ['ancervillois'] ['ancervillois']
# ancheens
# ['ancheens']
# Anché ['ancheens'] ['ancheens']
# ancinnois
# ['ancinnois']
# Ancinnes ['ancinnois'] ['ancinnois']
# ancizanois,  ancizanoises
# ['ancizanois', ' ancizanoises']
# Ancizan ['ancizanois,  ancizanoises'] ['ancizanois', ' ancizanoises']
# anctovillais
# ['anctovillais']
# Anctoville-sur-Boscq ['anctovillais'] ['anctovillais']
# anceens
# ['anceens']
# Ancy-Dornot ['anceens'] ['anceens']
# andancettois
# ['andancettois']
# Andancette ['andancettois'] ['andancettois']
# andelois, andeloise
# ['andelois', 'andeloise']
# Andel ['andelois, andeloise'] ['andeloise', 'andelois']
# andelnanais
# ['andelnanais']
# Andelnans ['andelnanais'] ['andelnanais']
# andelotiens
# ['andelotiens']
# Andelot-en-Montagne ['andelotiens'] ['andelotiens']
# chayants
# ['chayants']
# Andernay ['chayants'] ['chayants']
# andernosiens
# ['andernosiens']
# Andernos-les-Bains ['andernosiens'] ['andernosiens']
# andevilliens
# ['andevilliens']
# Andeville ['andevilliens'] ['andevilliens']
# andillacois
# ['andillacois']
# Andillac ['andillacois'] ['andillacois']
# andillais
# ['andillais']
# andillois
# ['andillois']
# andilliens
# ['andilliens']
# Andilly ['andillais', 'andillois', 'andilliens'] ['andillais', 'andillois', 'andilliens']
# andiranais
# ['andiranais']
# andiranaises
# ['andiranaises']
# Andiran ['andiranais', 'andiranaises'] ['andiranais', 'andiranaises']
# andlaviens, andlaviennes
# ['andlaviens', 'andlaviennes']
# Andlau ['andlaviens, andlaviennes'] ['andlaviens', 'andlaviennes']
# andosien
# ['andosien']
# Andoins ['andosien'] ['andosien']
# andolsheimois, andolsheimoises
# ['andolsheimois', 'andolsheimoises']
# Andolsheim ['andolsheimois, andolsheimoises'] ['andolsheimoises', 'andolsheimois']
# andonnais-thorencois
# ['andonnais-thorencois']
# Andon ['andonnais-thorencois'] ['andonnais-thorencois']
# andonvillois
# ['andonvillois']
# Andonville ['andonvillois'] ['andonvillois']
# andolleen
# ['andolleen']
# Andouillé ['andolleen'] ['andolleen']
# andouquois
# ['andouquois']
# Andouque ['andouquois'] ['andouquois']
# andreinais
# ['andreinais']
# Andrein ['andreinais'] ['andreinais']
# andrestois, andrestoises
# ['andrestois', 'andrestoises']
# Andrest ['andrestois, andrestoises'] ['andrestoises', 'andrestois']
# andrezeliens
# ['andrezeliens']
# Andrezel ['andrezeliens'] ['andrezeliens']
# androgien, androgienne
# ['androgien', 'androgienne']
# Andryes ['androgien, androgienne'] ['androgienne', 'androgien']
# andrezien boutheonnais
# ['andrezien boutheonnais']
# Andrézieux-Bouthéon ['andrezien boutheonnais'] ['andrezien boutheonnais']
# angayais , angayaise
# ['angayais', 'angayaise']
# Angaïs ['angayais / angayaise'] ['angayaise', 'angayais']
# angeacais
# ['angeacais']
# Angeac-Champagne ['angeacais'] ['angeacais']
# angeacais
# ['angeacais']
# Angeac-Charente ['angeacais'] ['angeacais']
# angelois
# ['angelois']
# Angeot ['angelois'] ['angelois']
# angevins
# ['angevins']
# Angers ['angevins'] ['angevins']
# angervillois
# ['angervillois']
# Angerville ['angervillois'] ['angervillois']
# angervillais
# ['angervillais']
# Angerville-Bailleul ['angervillais'] ['angervillais']
# angervillais
# ['angervillais']
# Angerville-l'Orcher ['angervillais'] ['angervillais']
# angervillierois
# ['angervillierois']
# Angervilliers ['angervillierois'] ['angervillierois']
# angevillois, angevilloises
# ['angevillois', 'angevilloises']
# Angevillers ['angevillois, angevilloises'] ['angevillois', 'angevilloises']
# angicourtois,andevilliens
# ['angicourtois', 'andevilliens']
# Angicourt ['angicourtois ou andevilliens'] ['andevilliens', 'angicourtois']
# angladais
# ['angladais']
# Anglade ['angladais'] ['angladais']
# anglarcois
# ['anglarcois']
# Anglars-Saint-Félix ['anglarcois'] ['anglarcois']
# clafordans
# ['clafordans']
# Anglefort ['clafordans'] ['clafordans']
# anglemontais
# ['anglemontais']
# Anglemont ['anglemontais(es)'] ['anglemontais']
# anglois, angloise
# ['anglois', 'angloise']
# anglesiens
# ['anglesiens']
# Angles ['anglois, angloise', 'anglesiens'] ['angloise', 'anglois', 'anglesiens']
# anglois
# ['anglois']
# Angles-sur-l'Anglin ['anglois'] ['anglois']
# anglesquevillais
# ['anglesquevillais']
# Anglesqueville-la-Bras-Long ['anglesquevillais'] ['anglesquevillais']
# angloy
# ['angloy']
# Anglet ['angloy'] ['angloy']
# anglesien
# ['anglesien']
# anglesiens
# ['anglesiens']
# Angliers ['anglesien', 'anglesiens'] ['anglesiens', 'anglesien']
# les angluriots,les angluriotes.
# ['les angluriots', 'les angluriotes.']
# Anglure ['les angluriots et les angluriotes.'] ['les angluriotes.', 'les angluriots']
# anglois, angloise
# ['anglois', 'angloise']
# anglesiens
# ['anglesiens']
# Anglès ['anglois, angloise', 'anglesiens'] ['angloise', 'anglois', 'anglesiens']
# angoissais
# ['angoissais']
# Angoisse ['angoissais'] ['angoissais']
# angosois, angosoises
# ['angosois', 'angosoises']
# Angos ['angosois, angosoises'] ['angosoises', 'angosois']
# angoulinois
# ['angoulinois']
# Angoulins ['angoulinois'] ['angoulinois']
# angoumoisins
# ['angoumoisins']
# Angoulême ['angoumoisins'] ['angoumoisins']
# angousien
# ['angousien']
# Angous ['angousien'] ['angousien']
# angoustrinois
# ['angoustrinois']
# Angoustrine-Villeneuve-des-Escaldes ['angoustrinois(es)'] ['angoustrinois']
# angrien
# ['angrien']
# Angrie ['angrien'] ['angrien']
# angylois
# ['angylois']
# Angy ['angylois'] ['angylois']
# anhauztar
# ['anhauztar']
# Anhaux ['anhauztar'] ['anhauztar']
# anhiersois
# ['anhiersois']
# Anhiers ['anhiersois'] ['anhiersois']
# anianais
# ['anianais']
# Aniane ['anianais'] ['anianais']
# anichois, anichoises
# ['anichois', 'anichoises']
# Aniche ['anichois, anichoises'] ['anichoises', 'anichois']
# anisiens
# ['anisiens']
# Anisy ['anisiens'] ['anisiens']
# anjouinais
# ['anjouinais']
# Anjouin ['anjouinais'] ['anjouinais']
# anjoutinois
# ['anjoutinois']
# Anjoutey ['anjoutinois'] ['anjoutinois']
# anlageois
# ['anlageois']
# Anla ['anlageois'] ['anlageois']
# annaysiens, annaysiennes
# ['annaysiens', 'annaysiennes']
# Annay ['annaysiens, annaysiennes'] ['annaysiens', 'annaysiennes']
# anneciens
# ['anneciens']
# Annecy ['anneciens'] ['anneciens']
# annemassiennes, annemassiens
# ['annemassiennes', 'annemassiens']
# Annemasse ['annemassiennes, annemassiens'] ['annemassiens', 'annemassiennes']
# annepontois
# ['annepontois']
# Annepont ['annepontois'] ['annepontois']
# annessois , gravellois
# ['annessois', 'gravellois']
# Annesse-et-Beaulieu ['annessois ; gravellois'] ['annessois', 'gravellois']
# annetois
# ['annetois']
# Annet-sur-Marne ['annetois'] ['annetois']
# anneusiens
# ['anneusiens']
# Anneux ['anneusiens'] ['anneusiens']
# annevillais
# ['annevillais']
# Anneville-en-Saire ['annevillais'] ['annevillais']
# anneziens
# ['anneziens']
# Annezay ['anneziens'] ['anneziens']
# annezinois
# ['annezinois']
# Annezin ['annezinois'] ['annezinois']
# annoneens,annoneennes
# ['annoneens', 'annoneennes']
# Annonay ['annoneens et annoneennes'] ['annoneens', 'annoneennes']
# annotains
# ['annotains']
# Annot ['annotains'] ['annotains']
# annovillais
# ['annovillais']
# Annoville ['annovillais'] ['annovillais']
# anorien, anorienne
# ['anorien', 'anorienne']
# Anor ['anorien, anorienne'] ['anorienne', 'anorien']
# anosien
# ['anosien']
# Anos ['anosien'] ['anosien']
# aulnois
# ['aulnois']
# Anould ['aulnois'] ['aulnois']
# ansacois
# ['ansacois']
# Ansac-sur-Vienne ['ansacois'] ['ansacois']
# ansacquois
# ['ansacquois']
# Ansacq ['ansacquois'] ['ansacquois']
# ansannais
# ['ansannais']
# Ansan ['ansannais'] ['ansannais']
# ansauvillois,ansauvillersois
# ['ansauvillois', 'ansauvillersois']
# Ansauvillers ['ansauvillois ou ansauvillersois'] ['ansauvillois', 'ansauvillersois']
# ansois
# ['ansois']
# Anse ['ansois'] ['ansois']
# ansois
# ['ansois']
# Anse-Bertrand ['ansois'] ['ansois']
# ansignanais
# ['ansignanais']
# Ansignan ['ansignanais(es)'] ['ansignanais']
# ansostois, ansostoise
# ['ansostois', 'ansostoise']
# Ansost ['ansostois, ansostoise'] ['ansostois', 'ansostoise']
# ansouisiens
# ['ansouisiens']
# Ansouis ['ansouisiens'] ['ansouisiens']
# anstinois
# ['anstinois']
# Anstaing ['anstinois'] ['anstinois']
# antagnacais
# ['antagnacais']
# Antagnac ['antagnacais'] ['antagnacais']
# anteuillois
# ['anteuillois']
# Anteuil ['anteuillois'] ['anteuillois']
# antezantais
# ['antezantais']
# Antezant-la-Chapelle ['antezantais'] ['antezantais']
# antheuillais
# ['antheuillais']
# Antheuil-Portes ['antheuillais'] ['antheuillais']
# anthonois
# ['anthonois']
# Anthon ['anthonois'] ['anthonois']
# anthychois , anthychoise
# ['anthychois', 'anthychoise']
# Anthy-sur-Léman ['anthychois / anthychoise'] ['anthychois', 'anthychoise']
# antibois
# ['antibois']
# Antibes ['antibois'] ['antibois']
# antichanois
# ['antichanois']
# Antichan ['antichanois'] ['antichanois']
# antichanais
# ['antichanais']
# Antichan-de-Frontignes ['antichanais'] ['antichanais']
# antignacois
# ['antignacois']
# Antignac ['antignacois'] ['antignacois']
# antignois
# ['antignois']
# antignolais
# ['antignolais']
# Antigny ['antignois', 'antignolais'] ['antignois', 'antignolais']
# antinois, antinoises
# ['antinois', 'antinoises']
# Antin ['antinois, antinoises'] ['antinois', 'antinoises']
# antisantais
# ['antisantais']
# antisantichi
# ['antisantichi']
# Antisanti ['antisantais', 'antisantichi'] ['antisantais', 'antisantichi']
# antistois, antistoises
# ['antistois', 'antistoises']
# Antist ['antistois, antistoises'] ['antistoises', 'antistois']
# antoigneens
# ['antoigneens']
# Antoigné ['antoigneens'] ['antoigneens']
# antoniens
# ['antoniens']
# Antony ['antoniens'] ['antoniens']
# antranais
# ['antranais']
# Antran ['antranais'] ['antranais']
# antrasois
# ['antrasois']
# antrassien, antrassienne
# ['antrassien', 'antrassienne']
# Antras ['antrasois', 'antrassien, antrassienne'] ['antrasois', 'antrassienne', 'antrassien']
# antugnacois
# ['antugnacois']
# Antugnac ['antugnacois'] ['antugnacois']
# pilavoines
# ['pilavoines']
# Antully ['pilavoines'] ['pilavoines']
# anvinois
# ['anvinois']
# Anvin ['anvinois'] ['anvinois']
# anzexois
# ['anzexois']
# anzexoises
# ['anzexoises']
# Anzex ['anzexois', 'anzexoises'] ['anzexois', 'anzexoises']
# anzinois
# ['anzinois']
# Anzin ['anzinois'] ['anzinois']
# anzinois
# ['anzinois']
# Anzin-Saint-Aubin ['anzinois'] ['anzinois']
# aouziens
# ['aouziens']
# Aouze ['aouzien(ne)s'] ['aouziens']
# apinaquois
# ['apinaquois']
# Apinac ['apinaquois'] ['apinaquois']
# appelois
# ['appelois']
# Appelle ['appelois'] ['appelois']
# appenwihroi
# ['appenwihroi']
# Appenwihr ['appenwihroi(se)'] ['appenwihroi']
# appevillais
# ['appevillais']
# Appeville ['appevillais'] ['appevillais']
# eponiens
# ['eponiens']
# Appoigny ['eponiens'] ['eponiens']
# apprelans
# ['apprelans']
# Apprieu ['apprelans'] ['apprelans']
# apremontais
# ['apremontais']
# apremontois
# ['apremontois']
# apremolains
# ['apremolains']
# Apremont ['apremontais', 'apremontois', 'apremolains(es)'] ['apremontais', 'apremolains', 'apremontois']
# asperomontais
# ['asperomontais']
# Apremont-la-Forêt ['asperomontais'] ['asperomontais']
# aptesiens,aptois
# ['aptesiens', 'aptois']
# Apt ['aptesiens ou aptois'] ['aptesiens', 'aptois']
# arabausois
# ['arabausois']
# Arabaux ['arabausois'] ['arabausois']
# aragonais
# ['aragonais']
# Aragon ['aragonais'] ['aragonais']
# aramitsien
# ['aramitsien']
# Aramits ['aramitsien'] ['aramitsien']
# randaoillards
# ['randaoillards']
# Aranc ['randaoillards'] ['randaoillards']
# arancoi
# ['arancoi']
# Arancou ['arancoi'] ['arancoi']
# carcaillons
# ['carcaillons']
# Arandas ['carcaillons'] ['carcaillons']
# araujuzonais
# ['araujuzonais']
# Araujuzon ['araujuzonais'] ['araujuzonais']
# araulais
# ['araulais']
# Araules ['araulais'] ['araulais']
# arbanatais
# ['arbanatais']
# Arbanats ['arbanatais'] ['arbanatais']
# arbasiens
# ['arbasiens']
# Arbas ['arbasiens'] ['arbasiens']
# arbiddalinchi
# ['arbiddalinchi']
# arbellarais
# ['arbellarais']
# Arbellara ['arbiddalinchi', 'arbellarais'] ['arbiddalinchi', 'arbellarais']
# arbanais
# ['arbanais']
# Arbent ['arbanais'] ['arbanais']
# arbladais, arbladaise
# ['arbladais', 'arbladaise']
# Arblade-le-Bas ['arbladais, arbladaise'] ['arbladaise', 'arbladais']
# arbladois, arbladoise
# ['arbladois', 'arbladoise']
# Arblade-le-Haut ['arbladois, arbladoise'] ['arbladoise', 'arbladois']
# arboisiens
# ['arboisiens']
# Arbois ['arboisiens'] ['arboisiens']
# arbonnais
# ['arbonnais']
# Arbon ['arbonnais'] ['arbonnais']
# arbonars
# ['arbonars']
# Arbonne ['arbonars'] ['arbonars']
# arbonnais
# ['arbonnais']
# Arbonne-la-Forêt ['arbonnais'] ['arbonnais']
# arborassiens
# ['arborassiens']
# Arboras ['arborassiens'] ['arborassiens']
# arburesi
# ['arburesi']
# Arbori ['arburesi'] ['arburesi']
# arbouannais,
# ['arbouannais', '']
# Arbouans ['arbouannais, (historiquement : ours)'] ['', 'arbouannais']
# arbotiar
# ['arbotiar']
# Arbouet-Sussaute ['arbotiar'] ['arbotiar']
# arboussolois, arboussoloises
# ['arboussolois', 'arboussoloises']
# Arboussols ['arboussolois, arboussoloises'] ['arboussolois', 'arboussoloises']
# arbrisselois
# ['arbrisselois']
# Arbrissel ['arbrisselois'] ['arbrisselois']
# arbusien
# ['arbusien']
# Arbus ['arbusien'] ['arbusien']
# arberaztar
# ['arberaztar']
# Arbérats-Sillègue ['arberaztar'] ['arberaztar']
# arcois
# ['arcois']
# Arc-lès-Gray ['arcois'] ['arcois']
# arcachonnais
# ['arcachonnais']
# Arcachon ['arcachonnais'] ['arcachonnais']
# arcanguais
# ['arcanguais']
# Arcangues ['arcanguais'] ['arcanguais']
# arcillons
# ['arcillons']
# Arces ['arcillons'] ['arcillons']
# archailois
# ['archailois']
# Archail ['archailois'] ['archailois']
# archampois , archampoise
# ['archampois', 'archampoise']
# Archamps ['archampois / archampoise'] ['archampoise', 'archampois']
# archeens
# ['archeens']
# Arches ['archeen(ne)s'] ['archeens']
# archettois
# ['archettois']
# Archettes ['archettois'] ['archettois']
# archiacais
# ['archiacais']
# Archiac ['archiacais'] ['archiacais']
# archignois
# ['archignois']
# Archigny ['archignois'] ['archignois']
# arcantois
# ['arcantois']
# Archingeay ['arcantois'] ['arcantois']
# blottis, blottise
# ['blottis', 'blottise']
# Arcinges ['blottis, blottise'] ['blottise', 'blottis']
# arcinois
# ['arcinois']
# Arcins ['arcinois'] ['arcinois']
# arcizacois, arcizacoises
# ['arcizacois', 'arcizacoises']
# Arcizac-Adour ['arcizacois, arcizacoises'] ['arcizacois', 'arcizacoises']
# arcizacais, arcizacaises
# ['arcizacais', 'arcizacaises']
# Arcizac-ez-Angles ['arcizacais, arcizacaises'] ['arcizacaises', 'arcizacais']
# arcizannais, arcizannaises
# ['arcizannais', 'arcizannaises']
# Arcizans-Avant ['arcizannais, arcizannaises'] ['arcizannaises', 'arcizannais']
# arcizanais, arcizanaises
# ['arcizanais', 'arcizanaises']
# Arcizans-Dessus ['arcizanais, arcizanaises'] ['arcizanaises', 'arcizanais']
# cailleux est le surnom pejoratif donner par les saugeais.
# ['cailleux est le surnom pejoratif donner par les saugeais.']
# arconais
# ['arconais']
# Arcon ['cailleux est le surnom pejoratif donner par les saugeais.', 'arconais'] ['cailleux est le surnom pejoratif donner par les saugeais.', 'arconais']
# arcueillais
# ['arcueillais']
# Arcueil ['arcueillais'] ['arcueillais']
# ardellois
# ['ardellois']
# Ardelles ['ardellois(e)'] ['ardellois']
# ardenaisien
# ['ardenaisien']
# Ardenay-sur-Mérize ['ardenaisien'] ['ardenaisien']
# ardengostois, ardengostoises
# ['ardengostois', 'ardengostoises']
# Ardengost ['ardengostois, ardengostoises'] ['ardengostois', 'ardengostoises']
# ardentais
# ['ardentais']
# Ardentes ['ardentais'] ['ardentais']
# ardoisiens
# ['ardoisiens']
# Ardes ['ardoisiens'] ['ardoisiens']
# ardillierois
# ['ardillierois']
# Ardillières ['ardillierois'] ['ardillierois']
# ardinois, ardinoises
# ['ardinois', 'ardinoises']
# Ardin ['ardinois, ardinoises'] ['ardinois', 'ardinoises']
# ardisois, ardisoise
# ['ardisois', 'ardisoise']
# Ardizas ['ardisois, ardisoise'] ['ardisois', 'ardisoise']
# ardiejois
# ['ardiejois']
# Ardiège ['ardiejois'] ['ardiejois']
# ardoisiens
# ['ardoisiens']
# Ardoix ['ardoisiens'] ['ardoisiens']
# ardonnais
# ['ardonnais']
# ardonais
# ['ardonais']
# Ardon ['ardonnais', 'ardonais'] ['ardonnais', 'ardonais']
# areinais
# ['areinais']
# Areines ['areinais'] ['areinais']
# aresyien
# ['aresyien']
# Aressy ['aresyien'] ['aresyien']
# arettois
# ['arettois']
# Arette ['arettois'] ['arettois']
# arfontais
# ['arfontais']
# Arfons ['arfontais'] ['arfontais']
# argagnonais
# ['argagnonais']
# Argagnon ['argagnonais'] ['argagnonais']
# arganchois
# ['arganchois']
# Arganchy ['arganchois'] ['arganchois']
# argenois
# ['argenois']
# Argein ['argenois'] ['argenois']
# argeliesois
# ['argeliesois']
# Argeliers ['argeliesois'] ['argeliesois']
# argellierains
# ['argellierains']
# Argelliers ['argellierains'] ['argellierains']
# argelesois, argelesoises
# ['argelesois', 'argelesoises']
# Argelès-Bagnères ['argelesois, argelesoises'] ['argelesoises', 'argelesois']
# argelesiens
# ['argelesiens']
# Argelès-Gazost ['argelesiens'] ['argelesiens']
# argelesiens, argelesiennes
# ['argelesiens', 'argelesiennes']
# Argelès-sur-Mer ['argelesiens, argelesiennes'] ['argelesiens', 'argelesiennes']
# argencais
# ['argencais']
# Argences ['argencais'] ['argencais']
# saint-genovefain
# ['saint-genovefain']
# Argences en Aubrac ['saint-genovefain(e)'] ['saint-genovefain']
# argentais
# ['argentais']
# Argent-sur-Sauldre ['argentais(es)'] ['argentais']
# argentanais
# ['argentanais']
# Argentan ['argentanais'] ['argentanais']
# argentacois
# ['argentacois']
# Argentat-sur-Dordogne ['argentacois'] ['argentacois']
# argenteuillais
# ['argenteuillais']
# Argenteuil ['argenteuillais'] ['argenteuillais']
# argentiers
# ['argentiers']
# Argentières ['argentiers'] ['argentiers']
# argentonnais
# ['argentonnais']
# Argenton ['argentonnais'] ['argentonnais']
# argentonnais
# ['argentonnais']
# Argenton-sur-Creuse ['argentonnais'] ['argentonnais']
# argentreens
# ['argentreens']
# Argentré ['argentreens'] ['argentreens']
# argentreens
# ['argentreens']
# Argentré-du-Plessis ['argentreens'] ['argentreens']
# arghjustesi
# ['arghjustesi']
# argiustais
# ['argiustais']
# Argiusta-Moriccio ['arghjustesi', 'argiustais'] ['arghjustesi', 'argiustais']
# argiesanais
# ['argiesanais']
# Argiésans ['argiesanais'] ['argiesanais']
# argoliens
# ['argoliens']
# Argol ['argoliens'] ['argoliens']
# argonautes
# ['argonautes']
# Argonay ['argonautes'] ['argonautes']
# arguelois, argueloises
# ['arguelois', 'argueloises']
# Arguel ['arguelois, argueloises'] ['argueloises', 'arguelois']
# arguenosiens, arguenosiennes
# ['arguenosiens', 'arguenosiennes']
# Arguenos ['arguenosiens, arguenosiennes'] ['arguenosiens', 'arguenosiennes']
# argutois
# ['argutois']
# Argut-Dessous ['argutois'] ['argutois']
# argyciens
# ['argyciens']
# Argy ['argyciens'] ['argyciens']
# arhantsusiar
# ['arhantsusiar']
# Arhansus ['arhantsusiar'] ['arhantsusiar']
# arienanois, arienanoises
# ['arienanois', 'arienanoises']
# Aries-Espénan ['arienanois, arienanoises'] ['arienanois', 'arienanoises']
# arifatois
# ['arifatois']
# Arifat ['arifatois'] ['arifatois']
# arignacois
# ['arignacois']
# Arignac ['arignacois'] ['arignacois']
# arlebossiens
# ['arlebossiens']
# Arlebosc ['arlebossiens'] ['arlebossiens']
# arlesiens
# ['arlesiens']
# Arles ['arlesiens'] ['arlesiens']
# arlesiens, arlesiennes
# ['arlesiens', 'arlesiennes']
# Arles-sur-Tech ['arlesiens, arlesiennes'] ['arlesiennes', 'arlesiens']
# arleuquins, arleuquines
# ['arleuquins', 'arleuquines']
# Arleuf ['arleuquins, arleuquines'] ['arleuquines', 'arleuquins']
# arleusiens
# ['arleusiens']
# Arleux ['arleusiens'] ['arleusiens']
# arlosiens
# ['arlosiens']
# Arlos ['arlosiens'] ['arlosiens']
# armailleens
# ['armailleens']
# Armaillé ['armailleens'] ['armailleens']
# armancourtois
# ['armancourtois']
# Armancourt ['armancourtois'] ['armancourtois']
# armbouts-cappellois
# ['armbouts-cappellois']
# Armbouts-Cappel ['armbouts-cappellois'] ['armbouts-cappellois']
# armendariztar
# ['armendariztar']
# Armendarits ['armendariztar'] ['armendariztar']
# armentieusois, armentieusoise
# ['armentieusois', 'armentieusoise']
# Armentieux ['armentieusois, armentieusoise'] ['armentieusoise', 'armentieusois']
# armentierois, armentieroises
# ['armentierois', 'armentieroises']
# Armentières ['armentierois, armentieroises'] ['armentieroises', 'armentierois']
# armentierois
# ['armentierois']
# Armentières-en-Brie ['armentierois'] ['armentierois']
# armentierois
# ['armentierois']
# Armentières-sur-Avre ['armentierois'] ['armentierois']
# armillacais
# ['armillacais']
# armillacaises
# ['armillacaises']
# Armillac ['armillacais', 'armillacaises'] ['armillacais', 'armillacaises']
# armissannais
# ['armissannais']
# Armissan ['armissannais'] ['armissannais']
# arcausien, arcausienne
# ['arcausien', 'arcausienne']
# Armous-et-Cau ['arcausien, arcausienne'] ['arcausienne', 'arcausien']
# armoisiens
# ['armoisiens']
# Armoy ['armoisiens'] ['armoisiens']
# arnacois
# ['arnacois']
# Arnac ['arnacois'] ['arnacois']
# pompadour
# ['pompadour']
# Arnac-Pompadour ['pompadour'] ['pompadour']
# arnacois
# ['arnacois']
# Arnac-la-Poste ['arnacois'] ['arnacois']
# arnacois, arnacoise
# ['arnacois', 'arnacoise']
# Arnac-sur-Dourdou ['arnacois, arnacoise'] ['arnacoise', 'arnacois']
# arnageois
# ['arnageois']
# Arnage ['arnageois'] ['arnageois']
# arnassiennes, arnassiens
# ['arnassiennes', 'arnassiens']
# Arnas ['arnassiennes, arnassiens'] ['arnassiennes', 'arnassiens']
# arnaud-guilhemois
# ['arnaud-guilhemois']
# Arnaud-Guilhem ['arnaud-guilhemois'] ['arnaud-guilhemois']
# arnavais
# ['arnavais']
# Arnave ['arnavais'] ['arnavais']
# arnavillois, arnavilloise
# ['arnavillois', 'arnavilloise']
# Arnaville ['arnavillois, arnavilloise'] ['arnavillois', 'arnavilloise']
# arnosien
# ['arnosien']
# Arnos ['arnosien'] ['arnosien']
# arnouvillois, arnouvilloises
# ['arnouvillois', 'arnouvilloises']
# Arnouville ['arnouvillois, arnouvilloises'] ['arnouvilloises', 'arnouvillois']
# arnekois, arnekoises
# ['arnekois', 'arnekoises']
# Arnèke ['arnekois, arnekoises'] ['arnekois', 'arnekoises']
# arnois, arnoises
# ['arnois', 'arnoises']
# Arné ['arnois, arnoises'] ['arnoises', 'arnois']
# arnegitar
# ['arnegitar']
# Arnéguy ['arnegitar'] ['arnegitar']
# aruffiens
# ['aruffiens']
# Aroffe ['aruffien(ne)s'] ['aruffiens']
# aronnais
# ['aronnais']
# Aron ['aronnais'] ['aronnais']
# aruetar
# ['aruetar']
# Aroue-Ithorots-Olhaïby ['aruetar'] ['aruetar']
# arpajonnais
# ['arpajonnais']
# Arpajon ['arpajonnais'] ['arpajonnais']
# arpheuillois
# ['arpheuillois']
# Arpheuilles ['arpheuillois'] ['arpheuillois']
# arquenaysien
# ['arquenaysien']
# Arquenay ['arquenaysien'] ['arquenaysien']
# arcasois
# ['arcasois']
# arquois, arquoises
# ['arquois', 'arquoises']
# arquois
# ['arquois']
# Arques ['arcasois', 'arquois, arquoises', 'arquois'] ['arcasois', 'arquois', 'arquoises']
# arquais
# ['arquais']
# Arques-la-Bataille ['arquais'] ['arquais']
# arquettois
# ['arquettois']
# Arquettes-en-Val ['arquettois'] ['arquettois']
# arquevois
# ['arquevois']
# Arquèves ['arquevois'] ['arquevois']
# arracourtois
# ['arracourtois']
# Arracourt ['arracourtois'] ['arracourtois']
# arradonnais
# ['arradonnais']
# Arradon ['arradonnais'] ['arradonnais']
# arrancourtois
# ['arrancourtois']
# Arrancourt ['arrancourtois'] ['arrancourtois']
# arrageois
# ['arrageois']
# Arras ['arrageois(e)'] ['arrageois']
# arrasiens, arrasiennes
# ['arrasiens', 'arrasiennes']
# Arras-en-Lavedan ['arrasiens, arrasiennes'] ['arrasiennes', 'arrasiens']
# urrustoitar
# ['urrustoitar']
# Arrast-Larrebieu ['urrustoitar'] ['urrustoitar']
# arruetar
# ['arruetar']
# Arraute-Charritte ['arruetar'] ['arruetar']
# lahittois
# ['lahittois']
# Arrayou-Lahitte ['lahittois'] ['lahittois']
# arrentais
# ['arrentais']
# Arrentès-de-Corcieux ['arrentais(es)'] ['arrentais']
# arrienois
# ['arrienois']
# Arrien-en-Bethmale ['arrienois'] ['arrienois']
# arrodetois
# ['arrodetois']
# Arrodets ['arrodetois'] ['arrodetois']
# ...
# ['fiolants', 'fiolantes']
# Ébreuil ['ebreugliens, ebreugliennes', 'fiolants, fiolantes'] ['ebreugliens', 'fiolantes', 'ebreugliennes', 'fiolants']
# ebreonais
# ['ebreonais']
# Ébréon ['ebreonais'] ['ebreonais']
# ecaillonnais, ecaillonnaises
# ['ecaillonnais', 'ecaillonnaises']
# Écaillon ['ecaillonnais, ecaillonnaises'] ['ecaillonnais', 'ecaillonnaises']
# ecallais
# ['ecallais']
# Écalles-Alix ['ecallais'] ['ecallais']
# ecaquelonais
# ['ecaquelonais']
# Écaquelon ['ecaquelonais'] ['ecaquelonais']
# ecardenvillais
# ['ecardenvillais']
# Écardenville-la-Campagne ['ecardenvillais'] ['ecardenvillais']
# ecaussevillais
# ['ecaussevillais']
# Écausseville ['ecaussevillais'] ['ecaussevillais']
# chalarons
# ['chalarons']
# Échalas ['chalarons'] ['chalarons']
# echalotais
# ['echalotais']
# Échalot ['echalotais'] ['echalotais']
# echaluviens
# ['echaluviens']
# Échalou ['echaluviens'] ['echaluviens']
# echarconnais
# ['echarconnais']
# Écharcon ['echarconnais'] ['echarconnais']
# echauffouriens
# ['echauffouriens']
# Échauffour ['echauffouriens'] ['echauffouriens']
# echavannais
# ['echavannais']
# Échavanne ['echavannais'] ['echavannais']
# echebrunois
# ['echebrunois']
# Échebrune ['echebrunois'] ['echebrunois']
# echeminois
# ['echeminois']
# Échemines ['echeminois'] ['echeminois']
# echenanais
# ['echenanais']
# Échenans-sous-Mont-Vaudois ['echenanais'] ['echenanais']
# epincellois
# ['epincellois']
# Échenay ['epincellois'] ['epincellois']
# chenevessiens,echenevessiens
# ['chenevessiens', 'echenevessiens']
# Échenevex ['chenevessiens ou echenevessiens'] ['echenevessiens', 'chenevessiens']
# melinois
# ['melinois']
# Échenoz-la-Méline ['melinois'] ['melinois']
# echevannais
# ['echevannais']
# Échevannes ['echevannais'] ['echevannais']
# cavisiens
# ['cavisiens']
# Échevis ['cavisiens'] ['cavisiens']
# echillaisiens
# ['echillaisiens']
# Échillais ['echillaisiens'] ['echillaisiens']
# rogants
# ['rogants']
# Échilleuses ['rogants'] ['rogants']
# echirollois
# ['echirollois']
# Échirolles ['echirollois'] ['echirollois']
# echireen
# ['echireen']
# Échiré ['echireen(ne)'] ['echireen']
# echouboulinois
# ['echouboulinois']
# Échouboulains ['echouboulinois'] ['echouboulinois']
# eclaibois
# ['eclaibois']
# Éclaibes ['eclaibois'] ['eclaibois']
# eclariste
# ['eclariste']
# Éclance ['eclariste'] ['eclariste']
# eclaronnais
# ['eclaronnais']
# Éclaron-Braucourt-Sainte-Livière ['eclaronnais'] ['eclaronnais']
# ecommeen
# ['ecommeen']
# Écommoy ['ecommeen'] ['ecommeen']
# ecorceiens
# ['ecorceiens']
# Écorcei ['ecorceiens'] ['ecorceiens']
# ecordaliens
# ['ecordaliens']
# Écordal ['ecordaliens'] ['ecordaliens']
# ecorpinois
# ['ecorpinois']
# Écorpain ['ecorpinois'] ['ecorpinois']
# ecubeens
# ['ecubeens']
# Écouché-les-Vallées ['ecubeens'] ['ecubeens']
# ecouennais
# ['ecouennais']
# Écouen ['ecouennais'] ['ecouennais']
# ecouflantais, ecouflantaise
# ['ecouflantais', 'ecouflantaise']
# Écouflant ['ecouflantais, ecouflantaise'] ['ecouflantais', 'ecouflantaise']
# ecoustois
# ['ecoustois']
# Écoust-Saint-Mein ['ecoustois'] ['ecoustois']
# radonnais
# ['radonnais']
# Écouves ['radonnais'] ['radonnais']
# ecouvissois
# ['ecouvissois']
# Écouviez ['ecouvissois'] ['ecouvissois']
# ecoziliens
# ['ecoziliens']
# Écoyeux ['ecoziliens'] ['ecoziliens']
# scrofuliens
# ['scrofuliens']
# Écrouves ['scrofuliens'] ['scrofuliens']
# ecueillois
# ['ecueillois']
# Écueillé ['ecueillois'] ['ecueillois']
# ecuilleen
# ['ecuilleen']
# Écuillé ['ecuilleen'] ['ecuilleen']
# ecullois
# ['ecullois']
# Écully ['ecullois'] ['ecullois']
# ecurassiens
# ['ecurassiens']
# Écuras ['ecurassiens'] ['ecurassiens']
# escuriens
# ['escuriens']
# Écurat ['escuriens'] ['escuriens']
# ecureuils
# ['ecureuils']
# Écurey-en-Verdunois ['ecureuils'] ['ecureuils']
# ecuriots, ecuriotes
# ['ecuriots', 'ecuriotes']
# Écury-sur-Coole ['ecuriots, ecuriotes'] ['ecuriots', 'ecuriotes']
# ecuelinois
# ['ecuelinois']
# Écuélin ['ecuelinois'] ['ecuelinois']
# edonais
# ['edonais']
# Édon ['edonais'] ['edonais']
# egatois
# ['egatois']
# Égat ['egatois(es)'] ['egatois']
# egletonnais, egletonnaise
# ['egletonnais', 'egletonnaise']
# Égletons ['egletonnais, egletonnaise'] ['egletonnais', 'egletonnaise']
# egliseneuvois
# ['egliseneuvois']
# Égliseneuve-près-Billom ['egliseneuvois'] ['egliseneuvois']
# aglagla
# ['aglagla']
# Égly ['aglagla'] ['aglagla']
# egrevillois
# ['egrevillois']
# Égreville ['egrevillois'] ['egrevillois']
# egrisellois
# ['egrisellois']
# Égriselles-le-Bocage ['egrisellois'] ['egrisellois']
# egryons
# ['egryons']
# Égry ['egryons'] ['egryons']
# eguillens
# ['eguillens']
# Éguilles ['eguillens'] ['eguillens']
# eguzonnais
# ['eguzonnais']
# Éguzon-Chantôme ['eguzonnais'] ['eguzonnais']
# elancourtois
# ['elancourtois']
# Élancourt ['elancourtois'] ['elancourtois']
# elesmois, elesmoises
# ['elesmois', 'elesmoises']
# Élesmes ['elesmois, elesmoises'] ['elesmoises', 'elesmois']
# eletotais, eletotaises
# ['eletotais', 'eletotaises']
# Életot ['eletotais, eletotaises'] ['eletotaises', 'eletotais']
# elincourtois, elincourtoises
# ['elincourtois', 'elincourtoises']
# Élincourt ['elincourtois, elincourtoises'] ['elincourtoises', 'elincourtois']
# elincourtois
# ['elincourtois']
# Élincourt-Sainte-Marguerite ['elincourtois'] ['elincourtois']
# eloyens
# ['eloyens']
# Éloie ['eloyens'] ['eloyens']
# eloisiens
# ['eloisiens']
# Éloise ['eloisiens'] ['eloisiens']
# loyas
# ['loyas']
# Éloyes ['loyas'] ['loyas']
# emagnynais
# ['emagnynais']
# Émagny ['emagnynais'] ['emagnynais']
# emallevillais
# ['emallevillais']
# Émalleville ['emallevillais'] ['emallevillais']
# emanceens
# ['emanceens']
# Émancé ['emanceens'] ['emanceens']
# emanvillais
# ['emanvillais']
# Émanville ['emanvillais'] ['emanvillais']
# emerainvillois
# ['emerainvillois']
# Émerainville ['emerainvillois'] ['emerainvillois']
# emerchicourtois
# ['emerchicourtois']
# Émerchicourt ['emerchicourtois'] ['emerchicourtois']
# emeringeons
# ['emeringeons']
# Émeringes ['emeringeons'] ['emeringeons']
# emievillais
# ['emievillais']
# Émiéville ['emievillais'] ['emievillais']
# emondevillais
# ['emondevillais']
# Émondeville ['emondevillais'] ['emondevillais']
# enencourtois
# ['enencourtois']
# Énencourt-Léage ['enencourtois'] ['enencourtois']
# epagnais
# ['epagnais']
# Épagne ['epagnais'] ['epagnais']
# epagnois
# ['epagnois']
# Épagne-Épagnette ['epagnois'] ['epagnois']
# spaniciens
# ['spaniciens']
# Épagny ['spaniciens'] ['spaniciens']
# epagnols, epagnoles
# ['epagnols', 'epagnoles']
# Épaignes ['epagnols, epagnoles'] ['epagnoles', 'epagnols']
# epaneens
# ['epaneens']
# Épaney ['epaneens'] ['epaneens']
# epargnais
# ['epargnais']
# Épargnes ['epargnais'] ['epargnais']
# spelterollitains
# ['spelterollitains']
# Épeautrolles ['spelterollitains'] ['spelterollitains']
# epeignois
# ['epeignois']
# Épeigné-les-Bois ['epeignois'] ['epeignois']
# spinacois
# ['spinacois']
# Épeigné-sur-Dême ['spinacois'] ['spinacois']
# spinosiens
# ['spinosiens']
# Épenouse ['spinosiens'] ['spinosiens']
# spinoyens
# ['spinoyens']
# Épenoy ['spinoyens'] ['spinoyens']
# epenedois
# ['epenedois']
# Épenède ['epenedois'] ['epenedois']
# sparcirots
# ['sparcirots']
# Épercieux-Saint-Paul ['sparcirots'] ['sparcirots']
# eperlecquois
# ['eperlecquois']
# Éperlecques ['eperlecquois'] ['eperlecquois']
# sparnaciens
# ['sparnaciens']
# Épernay ['sparnaciens'] ['sparnaciens']
# epernoniens
# ['epernoniens']
# sparnoniens
# ['sparnoniens']
# Épernon ['epernonien(ne)s', 'sparnonien(ne)s'] ['epernoniens', 'sparnoniens']
# epervanais
# ['epervanais']
# Épervans ['epervanais'] ['epervanais']
# epiais-rhussiens
# ['epiais-rhussiens']
# Épiais-Rhus ['epiais-rhussiens'] ['epiais-rhussiens']
# epiaisois,epiaisiens
# ['epiaisois', 'epiaisiens']
# Épiais-lès-Louvres ['epiaisois ou epiaisiens'] ['epiaisois', 'epiaisiens']
# epidoniens
# ['epidoniens']
# epiedois, epiedoise
# ['epiedois', 'epiedoise']
# spicariens
# ['spicariens']
# Épieds ['epidoniens', 'epiedois, epiedoise', 'spicariens'] ['epidoniens', 'epiedoise', 'epiedois', 'spicariens']
# spicaciens
# ['spicaciens']
# Épieds-en-Beauce ['spicaciens'] ['spicaciens']
# epierrains
# ['epierrains']
# Épierre ['epierrains'] ['epierrains']
# epinacois
# ['epinacois']
# Épinac ['epinacois'] ['epinacois']
# spinaliens
# ['spinaliens']
# Épinal ['spinaliens'] ['spinaliens']
# spinaciens
# ['spinaciens']
# Épinay-Champlâtreux ['spinaciens'] ['spinaciens']
# spinoliens
# ['spinoliens']
# Épinay-sous-Sénart ['spinoliens'] ['spinoliens']
# epinois
# ['epinois']
# Épinay-sur-Odon ['epinois'] ['epinois']
# spinoliens
# ['spinoliens']
# Épinay-sur-Orge ['spinoliens'] ['spinoliens']
# spinassiens
# ['spinassiens']
# Épinay-sur-Seine ['spinassiens'] ['spinassiens']
# spinoliens
# ['spinoliens']
# Épineau-les-Voves ['spinoliens'] ['spinoliens']
# spineens
# ['spineens']
# Épineu-le-Chevreuil ['spineens'] ['spineens']
# spinoliens,spinoliennes
# ['spinoliens', 'spinoliennes']
# Épineuil ['spinoliens et spinoliennes'] ['spinoliens', 'spinoliennes']
# epineuillois
# ['epineuillois']
# Épineuil-le-Fleuriel ['epineuillois'] ['epineuillois']
# spinosiens
# ['spinosiens']
# Épineuse ['spinosiens'] ['spinosiens']
# spinassiens
# ['spinassiens']
# Épinoy ['spinassiens'] ['spinassiens']
# epizonais
# ['epizonais']
# Épizon ['epizonais'] ['epizonais']
# eplessierois
# ['eplessierois']
# Éplessier ['eplessierois'] ['eplessierois']
# epothemontais
# ['epothemontais']
# Épothémont ['epothemontais'] ['epothemontais']
# epouvillais
# ['epouvillais']
# Épouville ['epouvillais'] ['epouvillais']
# epretotais
# ['epretotais']
# Épretot ['epretotais'] ['epretotais']
# eprevillais
# ['eprevillais']
# Épreville ['eprevillais'] ['eprevillais']
# eprevillais
# ['eprevillais']
# Épreville-en-Lieuvin ['eprevillais'] ['eprevillais']
# eprevillais
# ['eprevillais']
# Épreville-près-le-Neubourg ['eprevillais'] ['eprevillais']
# epronnais
# ['epronnais']
# Épron ['epronnais'] ['epronnais']
# equancourtois
# ['equancourtois']
# Équancourt ['equancourtois'] ['equancourtois']
# equemauvillais
# ['equemauvillais']
# Équemauville ['equemauvillais'] ['equemauvillais']
# equenois
# ['equenois']
# Équennes-Éramecourt ['equenois'] ['equenois']
# equevillonnais
# ['equevillonnais']
# Équevillon ['equevillonnais(es)'] ['equevillonnais']
# equihennois
# ['equihennois']
# Équihen-Plage ['equihennois'] ['equihennois']
# equillais
# ['equillais']
# Équilly ['equillais'] ['equillais']
# equirrois
# ['equirrois']
# Équirre ['equirrois'] ['equirrois']
# eragniens
# ['eragniens']
# Éragny ['eragniens'] ['eragniens']
# eragniens
# ['eragniens']
# Éragny-sur-Epte ['eragniens'] ['eragniens']
# eriziens
# ['eriziens']
# Érize-Saint-Dizier ['eriziens'] ['eriziens']
# eroudevillais
# ['eroudevillais']
# Éroudeville ['eroudevillais'] ['eroudevillais']
# ereacais, ereacaise
# ['ereacais', 'ereacaise']
# Éréac ['ereacais, ereacaise'] ['ereacais', 'ereacaise']
# eromains
# ['eromains']
# Érôme ['eromains'] ['eromains']
# etagnacois
# ['etagnacois']
# Étagnac ['etagnacois'] ['etagnacois']
# stainois
# ['stainois']
# Étain ['stainois'] ['stainois']
# etaignois
# ['etaignois']
# Étaing ['etaignois'] ['etaignois']
# stainhusiens
# ['stainhusiens']
# Étainhus ['stainhusiens'] ['stainhusiens']
# etaisiens
# ['etaisiens']
# Étais-la-Sauvin ['etaisiens'] ['etaisiens']
# estalanais
# ['estalanais']
# Étalans ['estalanais'] ['estalanais']
# etallevillais
# ['etallevillais']
# Étalleville ['etallevillais'] ['etallevillais']
# etalonien
# ['etalonien']
# Étalon ['etalonien'] ['etalonien']
# etalondais
# ['etalondais']
# Étalondes ['etalondais'] ['etalondais']
# etampois
# ['etampois']
# Étampes ['etampois'] ['etampois']
# etampois
# ['etampois']
# Étampes-sur-Marne ['etampois'] ['etampois']
# etaplois
# ['etaplois']
# Étaples ['etaplois'] ['etaplois']
# etaulais
# ['etaulais']
# Étaules ['etaulais'] ['etaulais']
# etaulois
# ['etaulois']
# Étauliers ['etaulois'] ['etaulois']
# etellois
# ['etellois']
# Étel ['etellois'] ['etellois']
# eterciens
# ['eterciens']
# Étercy ['eterciens'] ['eterciens']
# sterpiniens
# ['sterpiniens']
# Éterpigny ['sterpiniens'] ['sterpiniens']
# etervillais
# ['etervillais']
# Éterville ['etervillais'] ['etervillais']
# estivaliens
# ['estivaliens']
# Étevaux ['estivaliens'] ['estivaliens']
# etienvillais
# ['etienvillais']
# Étienville ['etienvillais'] ['etienvillais']
# stiniciens
# ['stiniciens']
# Étigny ['stiniciens'] ['stiniciens']
# etiollais
# ['etiollais']
# Étiolles ['etiollais'] ['etiollais']
# stivaliens
# ['stivaliens']
# Étival-Clairefontaine ['stivalien(e)s'] ['stivaliens']
# etivalois
# ['etivalois']
# Étival-lès-le-Mans ['etivalois'] ['etivalois']
# etiveens
# ['etiveens']
# Étivey ['etiveens'] ['etiveens']
# stolviciens
# ['stolviciens']
# Étourvy ['stolviciens'] ['stolviciens']
# etouttevillais
# ['etouttevillais']
# Étoutteville ['etouttevillais'] ['etouttevillais']
# etouvans
# ['etouvans']
# Étouvans ['etouvans'] ['etouvans']
# etouysiens
# ['etouysiens']
# Étouy ['etouysiens'] ['etouysiens']
# etrabonnais
# ['etrabonnais']
# Étrabonne ['etrabonnais'] ['etrabonnais']
# etrayens
# ['etrayens']
# Étraye ['etrayens'] ['etrayens']
# etrichiaciens
# ['etrichiaciens']
# Étrechet ['etrichiaciens'] ['etrichiaciens']
# etrellais
# ['etrellais']
# Étrelles ['etrellais'] ['etrellais']
# etrelliens
# ['etrelliens']
# Étrelles-et-la-Montbleuse ['etrelliens'] ['etrelliens']
# etrellois
# ['etrellois']
# Étrelles-sur-Aube ['etrellois'] ['etrellois']
# etrembierois
# ['etrembierois']
# Étrembières ['etrembierois'] ['etrembierois']
# estrepignacien
# ['estrepignacien']
# Étrepigney ['estrepignacien'] ['estrepignacien']
# stirpiens
# ['stirpiens']
# Étrepy ['stirpiens'] ['stirpiens']
# etriacais
# ['etriacais']
# Étriac ['etriacais'] ['etriacais']
# etricheen, etricheenne
# ['etricheen', 'etricheenne']
# Étriché ['etricheen, etricheenne'] ['etricheenne', 'etricheen']
# etroussatois, etroussatoises
# ['etroussatois', 'etroussatoises']
# Étroussat ['etroussatois, etroussatoises'] ['etroussatoises', 'etroussatois']
# strumensiens
# ['strumensiens']
# Étrun ['strumensiens'] ['strumensiens']
# strepiniacois
# ['strepiniacois']
# etrechiats
# ['etrechiats']
# etrechyssois
# ['etrechyssois']
# Étréchy ['strepiniacois', 'etrechiats', 'etrechyssois'] ['strepiniacois', 'etrechiats', 'etrechyssois']
# etrehamais
# ['etrehamais']
# Étréham ['etrehamais'] ['etrehamais']
# sterpinaciens
# ['sterpinaciens']
# Étrépagny ['sterpinaciens'] ['sterpinaciens']
# sterpiliaciens
# ['sterpiliaciens']
# Étrépilly ['sterpiliaciens'] ['sterpiliaciens']
# taffions
# ['taffions']
# Étueffont ['taffions'] ['taffions']
# erbatons
# ['erbatons']
# Étupes ['erbatons'] ['erbatons']
# etuziens
# ['etuziens']
# Étuz ['etuziens'] ['etuziens']
# evanais
# ['evanais']
# Évans ['evanais'] ['evanais']
# valmenilois
# ['valmenilois']
# Évaux-et-Ménil ['valmenilois(es)'] ['valmenilois']
# episcomontois
# ['episcomontois']
# Évecquemont ['episcomontois'] ['episcomontois']
# naizinois, naizinoise
# ['naizinois', 'naizinoise']
# Évellys ['naizinois, naizinoise'] ['naizinois', 'naizinoise']
# ebrosiens, ebrosiennes
# ['ebrosiens', 'ebrosiennes']
# Évenos ['ebrosiens, ebrosiennes'] ['ebrosiens', 'ebrosiennes']
# evalbertois
# ['evalbertois']
# Évette-Salbert ['evalbertois'] ['evalbertois']
# eveusiens
# ['eveusiens']
# Éveux ['eveusiens'] ['eveusiens']
# evianais, evianaise
# ['evianais', 'evianaise']
# Évian-les-Bains ['evianais, evianaise'] ['evianaise', 'evianais']
# avisiens
# ['avisiens']
# visinchi
# ['visinchi']
# Évisa ['avisiens', 'visinchi'] ['avisiens', 'visinchi']
# evosgiens
# ['evosgiens']
# Évosges ['evosgiens'] ['evosgiens']
# evrannais, evrannaise
# ['evrannais', 'evrannaise']
# Évran ['evrannais, evrannaise'] ['evrannais', 'evrannaise']
# ebroceens
# ['ebroceens']
# Évrecy ['ebroceens'] ['ebroceens']
# ebroicien, ebroicienne
# ['ebroicien', 'ebroicienne']
# Évreux ['ebroicien, ebroicienne'] ['ebroicien', 'ebroicienne']
# ebroiciens, ebroiciennes
# ['ebroiciens', 'ebroiciennes']
# Évricourt ['ebroiciens, ebroiciennes'] ['ebroiciens', 'ebroiciennes']
# evriguetois
# ['evriguetois']
# Évriguet ['evriguetois'] ['evriguetois']
# evronnais
# ['evronnais']
# Évron ['evronnais'] ['evronnais']
# evrytons
# ['evrytons']
# Évry ['evrytons'] ['evrytons']
# evryens
# ['evryens']
# Évry-Courcouronnes ['evryens'] ['evryens']
# everynois
# ['everynois']
# Évry-Grégy-sur-Yerre ['everynois'] ['everynois']
# ezanvillois
# ['ezanvillois']
# Ézanville ['ezanvillois'] ['ezanvillois']
# molenais
# ['molenais']
# Île-Molène ['molenais'] ['molenais']
# ile-tudistes
# ['ile-tudistes']
# Île-Tudy ['ile-tudistes'] ['ile-tudistes']
# ilois, iloises
# ['ilois', 'iloises']
# Île-aux-Moines ['ilois, iloises'] ['iloises', 'ilois']
# aixois
# ['aixois']
# Île-d'Aix ['aixois'] ['aixois']
# ildarais, ildaraise
# ['ildarais', 'ildaraise']
# Île-d'Arz ['ildarais, ildaraise'] ['ildarais', 'ildaraise']
# houatais
# ['houatais']
# Île-d'Houat ['houatais'] ['houatais']
# batziens,iliens
# ['batziens', 'iliens']
# Île-de-Batz ['batziens ou iliens'] ['iliens', 'batziens']
# brehatin, brehatine
# ['brehatin', 'brehatine']
# Île-de-Bréhat ['brehatin, brehatine'] ['brehatin', 'brehatine']
# senans
# ['senans']
# Île-de-Sein ['senans'] ['senans']

# %%
# # save in file
# with open("Data/dbPedia_extracted_demonyms3.json", "w") as fp:
#     json.dump(gentiles_,fp)

# %%
json_file1 = open("Data/dbPedia_extracted_demonyms3.json")
json_file2 = open("Data/infobox_extracted_demonyms.json")
gentiles1 = json.load(json_file1)
gentiles2 = json.load(json_file2)
len(gentiles1), len(gentiles2)
# Out:
# (15297, 22792)

# %%
s1 = set(list(gentiles1.keys()))
s2 = set(list(gentiles2.keys()))

# %%
len(s1), len(s2)
# Out:
# (15297, 22792)

# %%
s3 = s1.union(s2)

# %%
len(s3)
# Out:
# 22905
