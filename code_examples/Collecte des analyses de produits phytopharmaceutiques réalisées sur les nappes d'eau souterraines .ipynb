# %% [markdown]
# # Collecte des données d'analyse de produits phytopharmaceutiques diffusées par l'API Hub'Eau Qualité des nappes d'eau
# *Auteur : Antonio Andrade, ingénieur de données, [Office français de la biodiversité](https://ofb.gouv.fr/)*
# *Juillet 2023*

# %% [markdown]
# Ce notebook illustre l'utilisation de [Hub'Eau](https://hubeau.eaufrance.fr) pour télécharger les analyses de produits phytopharmaceutiques (PPP) diffusées par l'[API Qualité des nappes d'eau](https://hubeau.eaufrance.fr/page/api-qualite-nappes) Ces données sont produites ou collectées par le [BRGM](https://www.brgm.fr/fr) Elles sont rassemblées dans [Ades, la banque nationale des données sur les eaux souterraines](https://ades.eaufrance.fr/) et diffusées sous [Licence ouverte Etalab 2.0](https://www.etalab.gouv.fr/wp-content/uploads/2017/04/ETALAB-Licence-Ouverte-v2.0.pdf).
#
# Le traitement ciblera ici les analyses de PPP qualifiées de `correcte` réalisées entre 2021 et 2022. Cela représente un volume de plus de 8,6 millions d'analyses réalisées sur des dizaines de milliers de stations. Pour tenir compte de la limite de 20000 résultats maximum pour une recherche Hub'Eau, nous allons récupérer les données en suivant les étapes suivantes :
# 1. Récupération de la liste des départements français
# 2. Récupération de la liste des stations (point d'eau) pour chaque département
# 3. Consolidation de la liste des stations sur le territoire national
# 4. Récupération des analyses de PPP par groupe de 10 stations

# %% [markdown]
# ## Chargement des modules
# Commençons par charger les modules python nécessaires aux traitements :

# %%
import calendar
import io
import json
import os
import time

import pandas
import requests

print("Chargement OK")
# Out:
# Chargement OK

# %% [markdown]
# ## Paramétrage général des traitements
# Poursuivons avec le paramétrage général de nos traitements :

# %%
# Répertoire d'enregistrement des données téléchargées
data_folder_name = "data_20230721"
download_folder_path = os.getcwd() + "\\" + data_folder_name
if not os.path.exists(download_folder_path):
    os.mkdir(download_folder_path)

print("Paramétrage OK")
# Out:
# Paramétrage OK

# %% [markdown]
# ## Téléchargement des départements
# Commençons notre chaîne de traitement avec le téléchargement des données descriptives des stations de mesure. Leur nombre dépasse la limite de 20000 résultats pour une recherche Hub'Eau. Par conséquent, nous allons récupérer les données en itérant sur les départements. Pour récupérer, les données descriptives de ces derniers, nous allons utiliser l'[API Sandre Référentiel](https://www.sandre.eaufrance.fr/api-referentiel#).
#
# Construisons d'abord l'URL de téléchargement des données des départements :

# %%
# URL de base des API Sandre
base = "https://api.sandre.eaufrance.fr"
# Point d'accès de l'API Sandre Référentiel
endpoint = "referentiels/v1"
# Opération de téléchargement des données descriptives des communes administratives
operation = "dep"
# Format des données
format = "json"
# Schéma des données
schema = "SANDREv4"
# Construction de l'URL de téléchargement des données
url = f"{base}/{endpoint}/{operation}.{format}?outputSchema={schema}"
url
# Out:
# 'https://api.sandre.eaufrance.fr/referentiels/v1/dep.json?outputSchema=SANDREv4'

# %% [markdown]
# Téléchargeons maintenant les données :

# %%
# Interrogation de l'API
response = requests.get(url)
# Récupération des données dans un dictionnaire
response = response.json()
response
# Out:
# {'REFERENTIELS@attributes': {'xmlns': 'http://xml.sandre.eaufrance.fr/scenario/referentiel/4',
#   'xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance'},
#  'REFERENTIELS': {'Scenario': {'CodeScenario': 'REFERENTIEL',
#    'VersionScenario': '4',
#    'NomScenario': 'Diffusion de listes de référence par le Sandre',
#    'DateCreationFichier': '2023-06-29',
#    'DateDebutReference': '2023-01-01',
#    'DateFinReference': '2023-12-31',
#    'Emetteur': {'CdIntervenant@attributes': {'schemeAgencyID': 'SANDRE'},
#     'CdIntervenant': '1470',
#     'NomIntervenant': "Service d'Administration Nationale des Données et Référentiels sur l'Eau"}},
#   'Referentiel': {'CdReferentiel@attributes': {'schemeAgencyID': 'SANDRE'},
#    'CdReferentiel': 'Departement',
#    'NomReferentiel': 'Départements administratifs',
#    'TypeReferentiel': '2',
#    'StReferentiel': 'Validé',
#    'DateMajReferentiel': '2023-06-29T14:01:15',
#    'NbOccurrences': '101',
#    'SourceReferentiel': '10',
#    'VersionReferentiel': '2023',
#    'Departement': [{'CdDepartement': '01',
#      'LbDepartement': 'Ain',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '84', 'LbRegion': 'Auvergne-Rhône-Alpes'},
#      'CommuneChefLieu': {'CdCommune': '01053',
#       'LbCommune': 'Bourg-en-Bresse',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '02',
#      'LbDepartement': 'Aisne',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '32', 'LbRegion': 'Hauts-de-France'},
#      'CommuneChefLieu': {'CdCommune': '02408',
#       'LbCommune': 'Laon',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '03',
#      'LbDepartement': 'Allier',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '84', 'LbRegion': 'Auvergne-Rhône-Alpes'},
#      'CommuneChefLieu': {'CdCommune': '03190',
#       'LbCommune': 'Moulins',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '04',
#      'LbDepartement': 'Alpes-de-Haute-Provence',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '93', 'LbRegion': "Provence-Alpes-Côte d'Azur"},
#      'CommuneChefLieu': {'CdCommune': '04070',
#       'LbCommune': 'Digne-les-Bains',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '05',
#      'LbDepartement': 'Hautes-Alpes',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '93', 'LbRegion': "Provence-Alpes-Côte d'Azur"},
#      'CommuneChefLieu': {'CdCommune': '05061',
#       'LbCommune': 'Gap',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '06',
#      'LbDepartement': 'Alpes-Maritimes',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '93', 'LbRegion': "Provence-Alpes-Côte d'Azur"},
#      'CommuneChefLieu': {'CdCommune': '06088',
#       'LbCommune': 'Nice',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '07',
#      'LbDepartement': 'Ardèche',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '84', 'LbRegion': 'Auvergne-Rhône-Alpes'},
#      'CommuneChefLieu': {'CdCommune': '07186',
#       'LbCommune': 'Privas',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '08',
#      'LbDepartement': 'Ardennes',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '44', 'LbRegion': 'Grand Est'},
#      'CommuneChefLieu': {'CdCommune': '08105',
#       'LbCommune': 'Charleville-Mézières',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '09',
#      'LbDepartement': 'Ariège',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '76', 'LbRegion': 'Occitanie'},
#      'CommuneChefLieu': {'CdCommune': '09122',
#       'LbCommune': 'Foix',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '10',
#      'LbDepartement': 'Aube',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '44', 'LbRegion': 'Grand Est'},
#      'CommuneChefLieu': {'CdCommune': '10387',
#       'LbCommune': 'Troyes',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '11',
#      'LbDepartement': 'Aude',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '76', 'LbRegion': 'Occitanie'},
#      'CommuneChefLieu': {'CdCommune': '11069',
#       'LbCommune': 'Carcassonne',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '12',
#      'LbDepartement': 'Aveyron',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '76', 'LbRegion': 'Occitanie'},
#      'CommuneChefLieu': {'CdCommune': '12202',
#       'LbCommune': 'Rodez',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '13',
#      'LbDepartement': 'Bouches-du-Rhône',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '93', 'LbRegion': "Provence-Alpes-Côte d'Azur"},
#      'CommuneChefLieu': {'CdCommune': '13055',
#       'LbCommune': 'Marseille',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '14',
#      'LbDepartement': 'Calvados',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '28', 'LbRegion': 'Normandie'},
#      'CommuneChefLieu': {'CdCommune': '14118',
#       'LbCommune': 'Caen',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '15',
#      'LbDepartement': 'Cantal',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '84', 'LbRegion': 'Auvergne-Rhône-Alpes'},
#      'CommuneChefLieu': {'CdCommune': '15014',
#       'LbCommune': 'Aurillac',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '16',
#      'LbDepartement': 'Charente',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '75', 'LbRegion': 'Nouvelle-Aquitaine'},
#      'CommuneChefLieu': {'CdCommune': '16015',
#       'LbCommune': 'Angoulême',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '17',
#      'LbDepartement': 'Charente-Maritime',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '75', 'LbRegion': 'Nouvelle-Aquitaine'},
#      'CommuneChefLieu': {'CdCommune': '17300',
#       'LbCommune': 'La Rochelle',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '18',
#      'LbDepartement': 'Cher',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '24', 'LbRegion': 'Centre-Val de Loire'},
#      'CommuneChefLieu': {'CdCommune': '18033',
#       'LbCommune': 'Bourges',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '19',
#      'LbDepartement': 'Corrèze',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '75', 'LbRegion': 'Nouvelle-Aquitaine'},
#      'CommuneChefLieu': {'CdCommune': '19272',
#       'LbCommune': 'Tulle',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '21',
#      'LbDepartement': "Côte-d'Or",
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '27', 'LbRegion': 'Bourgogne-Franche-Comté'},
#      'CommuneChefLieu': {'CdCommune': '21231',
#       'LbCommune': 'Dijon',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '22',
#      'LbDepartement': "Côtes-d'Armor",
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '53', 'LbRegion': 'Bretagne'},
#      'CommuneChefLieu': {'CdCommune': '22278',
#       'LbCommune': 'Saint-Brieuc',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '23',
#      'LbDepartement': 'Creuse',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '75', 'LbRegion': 'Nouvelle-Aquitaine'},
#      'CommuneChefLieu': {'CdCommune': '23096',
#       'LbCommune': 'Guéret',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '24',
#      'LbDepartement': 'Dordogne',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '75', 'LbRegion': 'Nouvelle-Aquitaine'},
#      'CommuneChefLieu': {'CdCommune': '24322',
#       'LbCommune': 'Périgueux',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '25',
#      'LbDepartement': 'Doubs',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '27', 'LbRegion': 'Bourgogne-Franche-Comté'},
#      'CommuneChefLieu': {'CdCommune': '25056',
#       'LbCommune': 'Besançon',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '26',
#      'LbDepartement': 'Drôme',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '84', 'LbRegion': 'Auvergne-Rhône-Alpes'},
#      'CommuneChefLieu': {'CdCommune': '26362',
#       'LbCommune': 'Valence',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '27',
#      'LbDepartement': 'Eure',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '28', 'LbRegion': 'Normandie'},
#      'CommuneChefLieu': {'CdCommune': '27229',
#       'LbCommune': 'Évreux',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '28',
#      'LbDepartement': 'Eure-et-Loir',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '24', 'LbRegion': 'Centre-Val de Loire'},
#      'CommuneChefLieu': {'CdCommune': '28085',
#       'LbCommune': 'Chartres',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '29',
#      'LbDepartement': 'Finistère',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '53', 'LbRegion': 'Bretagne'},
#      'CommuneChefLieu': {'CdCommune': '29232',
#       'LbCommune': 'Quimper',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '2A',
#      'LbDepartement': 'Corse-du-Sud',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '94', 'LbRegion': 'Corse'},
#      'CommuneChefLieu': {'CdCommune': '2A004',
#       'LbCommune': 'Ajaccio',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '2B',
#      'LbDepartement': 'Haute-Corse',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '94', 'LbRegion': 'Corse'},
#      'CommuneChefLieu': {'CdCommune': '2B033',
#       'LbCommune': 'Bastia',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '30',
#      'LbDepartement': 'Gard',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '76', 'LbRegion': 'Occitanie'},
#      'CommuneChefLieu': {'CdCommune': '30189',
#       'LbCommune': 'Nîmes',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '31',
#      'LbDepartement': 'Haute-Garonne',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '76', 'LbRegion': 'Occitanie'},
#      'CommuneChefLieu': {'CdCommune': '31555',
#       'LbCommune': 'Toulouse',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '32',
#      'LbDepartement': 'Gers',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '76', 'LbRegion': 'Occitanie'},
#      'CommuneChefLieu': {'CdCommune': '32013',
#       'LbCommune': 'Auch',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '33',
#      'LbDepartement': 'Gironde',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '75', 'LbRegion': 'Nouvelle-Aquitaine'},
#      'CommuneChefLieu': {'CdCommune': '33063',
#       'LbCommune': 'Bordeaux',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '34',
#      'LbDepartement': 'Hérault',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '76', 'LbRegion': 'Occitanie'},
#      'CommuneChefLieu': {'CdCommune': '34172',
#       'LbCommune': 'Montpellier',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '35',
#      'LbDepartement': 'Ille-et-Vilaine',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '53', 'LbRegion': 'Bretagne'},
#      'CommuneChefLieu': {'CdCommune': '35238',
#       'LbCommune': 'Rennes',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '36',
#      'LbDepartement': 'Indre',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '24', 'LbRegion': 'Centre-Val de Loire'},
#      'CommuneChefLieu': {'CdCommune': '36044',
#       'LbCommune': 'Châteauroux',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '37',
#      'LbDepartement': 'Indre-et-Loire',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '24', 'LbRegion': 'Centre-Val de Loire'},
#      'CommuneChefLieu': {'CdCommune': '37261',
#       'LbCommune': 'Tours',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '38',
#      'LbDepartement': 'Isère',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '84', 'LbRegion': 'Auvergne-Rhône-Alpes'},
#      'CommuneChefLieu': {'CdCommune': '38185',
#       'LbCommune': 'Grenoble',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '39',
#      'LbDepartement': 'Jura',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '27', 'LbRegion': 'Bourgogne-Franche-Comté'},
#      'CommuneChefLieu': {'CdCommune': '39300',
#       'LbCommune': 'Lons-le-Saunier',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '40',
#      'LbDepartement': 'Landes',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '75', 'LbRegion': 'Nouvelle-Aquitaine'},
#      'CommuneChefLieu': {'CdCommune': '40192',
#       'LbCommune': 'Mont-de-Marsan',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '41',
#      'LbDepartement': 'Loir-et-Cher',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '24', 'LbRegion': 'Centre-Val de Loire'},
#      'CommuneChefLieu': {'CdCommune': '41018',
#       'LbCommune': 'Blois',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '42',
#      'LbDepartement': 'Loire',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '84', 'LbRegion': 'Auvergne-Rhône-Alpes'},
#      'CommuneChefLieu': {'CdCommune': '42218',
#       'LbCommune': 'Saint-Étienne',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '43',
#      'LbDepartement': 'Haute-Loire',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '84', 'LbRegion': 'Auvergne-Rhône-Alpes'},
#      'CommuneChefLieu': {'CdCommune': '43157',
#       'LbCommune': 'Le Puy-en-Velay',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '44',
#      'LbDepartement': 'Loire-Atlantique',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '52', 'LbRegion': 'Pays de la Loire'},
#      'CommuneChefLieu': {'CdCommune': '44109',
#       'LbCommune': 'Nantes',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '45',
#      'LbDepartement': 'Loiret',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '24', 'LbRegion': 'Centre-Val de Loire'},
#      'CommuneChefLieu': {'CdCommune': '45234',
#       'LbCommune': 'Orléans',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '46',
#      'LbDepartement': 'Lot',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '76', 'LbRegion': 'Occitanie'},
#      'CommuneChefLieu': {'CdCommune': '46042',
#       'LbCommune': 'Cahors',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '47',
#      'LbDepartement': 'Lot-et-Garonne',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '75', 'LbRegion': 'Nouvelle-Aquitaine'},
#      'CommuneChefLieu': {'CdCommune': '47001',
#       'LbCommune': 'Agen',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '48',
#      'LbDepartement': 'Lozère',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '76', 'LbRegion': 'Occitanie'},
#      'CommuneChefLieu': {'CdCommune': '48095',
#       'LbCommune': 'Mende',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '49',
#      'LbDepartement': 'Maine-et-Loire',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '52', 'LbRegion': 'Pays de la Loire'},
#      'CommuneChefLieu': {'CdCommune': '49007',
#       'LbCommune': 'Angers',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '50',
#      'LbDepartement': 'Manche',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '28', 'LbRegion': 'Normandie'},
#      'CommuneChefLieu': {'CdCommune': '50502',
#       'LbCommune': 'Saint-Lô',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '51',
#      'LbDepartement': 'Marne',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '44', 'LbRegion': 'Grand Est'},
#      'CommuneChefLieu': {'CdCommune': '51108',
#       'LbCommune': 'Châlons-en-Champagne',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '52',
#      'LbDepartement': 'Haute-Marne',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '44', 'LbRegion': 'Grand Est'},
#      'CommuneChefLieu': {'CdCommune': '52121',
#       'LbCommune': 'Chaumont',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '53',
#      'LbDepartement': 'Mayenne',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '52', 'LbRegion': 'Pays de la Loire'},
#      'CommuneChefLieu': {'CdCommune': '53130',
#       'LbCommune': 'Laval',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '54',
#      'LbDepartement': 'Meurthe-et-Moselle',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '44', 'LbRegion': 'Grand Est'},
#      'CommuneChefLieu': {'CdCommune': '54395',
#       'LbCommune': 'Nancy',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '55',
#      'LbDepartement': 'Meuse',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '44', 'LbRegion': 'Grand Est'},
#      'CommuneChefLieu': {'CdCommune': '55029',
#       'LbCommune': 'Bar-le-Duc',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '56',
#      'LbDepartement': 'Morbihan',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '53', 'LbRegion': 'Bretagne'},
#      'CommuneChefLieu': {'CdCommune': '56260',
#       'LbCommune': 'Vannes',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '57',
#      'LbDepartement': 'Moselle',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '44', 'LbRegion': 'Grand Est'},
#      'CommuneChefLieu': {'CdCommune': '57463',
#       'LbCommune': 'Metz',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '58',
#      'LbDepartement': 'Nièvre',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '27', 'LbRegion': 'Bourgogne-Franche-Comté'},
#      'CommuneChefLieu': {'CdCommune': '58194',
#       'LbCommune': 'Nevers',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '59',
#      'LbDepartement': 'Nord',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '32', 'LbRegion': 'Hauts-de-France'},
#      'CommuneChefLieu': {'CdCommune': '59350',
#       'LbCommune': 'Lille',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '60',
#      'LbDepartement': 'Oise',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '32', 'LbRegion': 'Hauts-de-France'},
#      'CommuneChefLieu': {'CdCommune': '60057',
#       'LbCommune': 'Beauvais',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '61',
#      'LbDepartement': 'Orne',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '28', 'LbRegion': 'Normandie'},
#      'CommuneChefLieu': {'CdCommune': '61001',
#       'LbCommune': 'Alençon',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '62',
#      'LbDepartement': 'Pas-de-Calais',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '32', 'LbRegion': 'Hauts-de-France'},
#      'CommuneChefLieu': {'CdCommune': '62041',
#       'LbCommune': 'Arras',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '63',
#      'LbDepartement': 'Puy-de-Dôme',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '84', 'LbRegion': 'Auvergne-Rhône-Alpes'},
#      'CommuneChefLieu': {'CdCommune': '63113',
#       'LbCommune': 'Clermont-Ferrand',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '64',
#      'LbDepartement': 'Pyrénées-Atlantiques',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '75', 'LbRegion': 'Nouvelle-Aquitaine'},
#      'CommuneChefLieu': {'CdCommune': '64445',
#       'LbCommune': 'Pau',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '65',
#      'LbDepartement': 'Hautes-Pyrénées',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '76', 'LbRegion': 'Occitanie'},
#      'CommuneChefLieu': {'CdCommune': '65440',
#       'LbCommune': 'Tarbes',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '66',
#      'LbDepartement': 'Pyrénées-Orientales',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '76', 'LbRegion': 'Occitanie'},
#      'CommuneChefLieu': {'CdCommune': '66136',
#       'LbCommune': 'Perpignan',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '67',
#      'LbDepartement': 'Bas-Rhin',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '44', 'LbRegion': 'Grand Est'},
#      'CommuneChefLieu': {'CdCommune': '67482',
#       'LbCommune': 'Strasbourg',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '68',
#      'LbDepartement': 'Haut-Rhin',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '44', 'LbRegion': 'Grand Est'},
#      'CommuneChefLieu': {'CdCommune': '68066',
#       'LbCommune': 'Colmar',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '69',
#      'LbDepartement': 'Rhône',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '84', 'LbRegion': 'Auvergne-Rhône-Alpes'},
#      'CommuneChefLieu': {'CdCommune': '69123',
#       'LbCommune': 'Lyon',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '70',
#      'LbDepartement': 'Haute-Saône',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '27', 'LbRegion': 'Bourgogne-Franche-Comté'},
#      'CommuneChefLieu': {'CdCommune': '70550',
#       'LbCommune': 'Vesoul',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '71',
#      'LbDepartement': 'Saône-et-Loire',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '27', 'LbRegion': 'Bourgogne-Franche-Comté'},
#      'CommuneChefLieu': {'CdCommune': '71270',
#       'LbCommune': 'Mâcon',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '72',
#      'LbDepartement': 'Sarthe',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '52', 'LbRegion': 'Pays de la Loire'},
#      'CommuneChefLieu': {'CdCommune': '72181',
#       'LbCommune': 'Le Mans',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '73',
#      'LbDepartement': 'Savoie',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '84', 'LbRegion': 'Auvergne-Rhône-Alpes'},
#      'CommuneChefLieu': {'CdCommune': '73065',
#       'LbCommune': 'Chambéry',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '74',
#      'LbDepartement': 'Haute-Savoie',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '84', 'LbRegion': 'Auvergne-Rhône-Alpes'},
#      'CommuneChefLieu': {'CdCommune': '74010',
#       'LbCommune': 'Annecy',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '75',
#      'LbDepartement': 'Paris',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '11', 'LbRegion': 'Île-de-France'},
#      'CommuneChefLieu': {'CdCommune': '75056',
#       'LbCommune': 'Paris',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '76',
#      'LbDepartement': 'Seine-Maritime',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '28', 'LbRegion': 'Normandie'},
#      'CommuneChefLieu': {'CdCommune': '76540',
#       'LbCommune': 'Rouen',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '77',
#      'LbDepartement': 'Seine-et-Marne',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '11', 'LbRegion': 'Île-de-France'},
#      'CommuneChefLieu': {'CdCommune': '77288',
#       'LbCommune': 'Melun',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '78',
#      'LbDepartement': 'Yvelines',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '11', 'LbRegion': 'Île-de-France'},
#      'CommuneChefLieu': {'CdCommune': '78646',
#       'LbCommune': 'Versailles',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '79',
#      'LbDepartement': 'Deux-Sèvres',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '75', 'LbRegion': 'Nouvelle-Aquitaine'},
#      'CommuneChefLieu': {'CdCommune': '79191',
#       'LbCommune': 'Niort',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '80',
#      'LbDepartement': 'Somme',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '32', 'LbRegion': 'Hauts-de-France'},
#      'CommuneChefLieu': {'CdCommune': '80021',
#       'LbCommune': 'Amiens',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '81',
#      'LbDepartement': 'Tarn',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '76', 'LbRegion': 'Occitanie'},
#      'CommuneChefLieu': {'CdCommune': '81004',
#       'LbCommune': 'Albi',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '82',
#      'LbDepartement': 'Tarn-et-Garonne',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '76', 'LbRegion': 'Occitanie'},
#      'CommuneChefLieu': {'CdCommune': '82121',
#       'LbCommune': 'Montauban',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '83',
#      'LbDepartement': 'Var',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '93', 'LbRegion': "Provence-Alpes-Côte d'Azur"},
#      'CommuneChefLieu': {'CdCommune': '83137',
#       'LbCommune': 'Toulon',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '84',
#      'LbDepartement': 'Vaucluse',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '93', 'LbRegion': "Provence-Alpes-Côte d'Azur"},
#      'CommuneChefLieu': {'CdCommune': '84007',
#       'LbCommune': 'Avignon',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '85',
#      'LbDepartement': 'Vendée',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '52', 'LbRegion': 'Pays de la Loire'},
#      'CommuneChefLieu': {'CdCommune': '85191',
#       'LbCommune': 'La Roche-sur-Yon',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '86',
#      'LbDepartement': 'Vienne',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '75', 'LbRegion': 'Nouvelle-Aquitaine'},
#      'CommuneChefLieu': {'CdCommune': '86194',
#       'LbCommune': 'Poitiers',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '87',
#      'LbDepartement': 'Haute-Vienne',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '75', 'LbRegion': 'Nouvelle-Aquitaine'},
#      'CommuneChefLieu': {'CdCommune': '87085',
#       'LbCommune': 'Limoges',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '88',
#      'LbDepartement': 'Vosges',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '44', 'LbRegion': 'Grand Est'},
#      'CommuneChefLieu': {'CdCommune': '88160',
#       'LbCommune': 'Épinal',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '89',
#      'LbDepartement': 'Yonne',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '27', 'LbRegion': 'Bourgogne-Franche-Comté'},
#      'CommuneChefLieu': {'CdCommune': '89024',
#       'LbCommune': 'Auxerre',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '90',
#      'LbDepartement': 'Territoire de Belfort',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '27', 'LbRegion': 'Bourgogne-Franche-Comté'},
#      'CommuneChefLieu': {'CdCommune': '90010',
#       'LbCommune': 'Belfort',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '91',
#      'LbDepartement': 'Essonne',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '11', 'LbRegion': 'Île-de-France'},
#      'CommuneChefLieu': {'CdCommune': '91228',
#       'LbCommune': 'Évry-Courcouronnes',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '92',
#      'LbDepartement': 'Hauts-de-Seine',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '11', 'LbRegion': 'Île-de-France'},
#      'CommuneChefLieu': {'CdCommune': '92050',
#       'LbCommune': 'Nanterre',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '93',
#      'LbDepartement': 'Seine-Saint-Denis',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '11', 'LbRegion': 'Île-de-France'},
#      'CommuneChefLieu': {'CdCommune': '93008',
#       'LbCommune': 'Bobigny',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '94',
#      'LbDepartement': 'Val-de-Marne',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '11', 'LbRegion': 'Île-de-France'},
#      'CommuneChefLieu': {'CdCommune': '94028',
#       'LbCommune': 'Créteil',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '95',
#      'LbDepartement': "Val-d'Oise",
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '11', 'LbRegion': 'Île-de-France'},
#      'CommuneChefLieu': {'CdCommune': '95500',
#       'LbCommune': 'Pontoise',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '971',
#      'LbDepartement': 'Guadeloupe',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '01', 'LbRegion': 'Guadeloupe'},
#      'CommuneChefLieu': {'CdCommune': '97105',
#       'LbCommune': 'Basse-Terre',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '972',
#      'LbDepartement': 'Martinique',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '02', 'LbRegion': 'Martinique'},
#      'CommuneChefLieu': {'CdCommune': '97209',
#       'LbCommune': 'Fort-de-France',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '973',
#      'LbDepartement': 'Guyane',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '03', 'LbRegion': 'Guyane'},
#      'CommuneChefLieu': {'CdCommune': '97302',
#       'LbCommune': 'Cayenne',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '974',
#      'LbDepartement': 'La Réunion',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '04', 'LbRegion': 'La Réunion'},
#      'CommuneChefLieu': {'CdCommune': '97411',
#       'LbCommune': 'Saint-Denis',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}},
#     {'CdDepartement': '976',
#      'LbDepartement': 'Mayotte',
#      'StDepartement': 'Validé',
#      'Region': {'CdRegion': '06', 'LbRegion': 'Mayotte'},
#      'CommuneChefLieu': {'CdCommune': '97608',
#       'LbCommune': 'Dzaoudzi',
#       'SourceReferentiel': '10',
#       'VersionReferentiel': '2023'}}]}}}

# %% [markdown]
# Récupérons dans la réponse de l'API Les données descriptives des départements :

# %%
departements = response["REFERENTIELS"]["Referentiel"]["Departement"]
departements[0]
# Out:
# {'CdDepartement': '01',
#  'LbDepartement': 'Ain',
#  'StDepartement': 'Validé',
#  'Region': {'CdRegion': '84', 'LbRegion': 'Auvergne-Rhône-Alpes'},
#  'CommuneChefLieu': {'CdCommune': '01053',
#   'LbCommune': 'Bourg-en-Bresse',
#   'SourceReferentiel': '10',
#   'VersionReferentiel': '2023'}}

# %% [markdown]
# ## Téléchargement des données Hub'Eau
# Pour faciliter les échanges avec Hub'Eau, définissons une fonction de téléchargement de données :

# %%
def get_data(url):
    MAX_TRY = 5 # Nombre max de tentatives d'interrogation
    DELAY_BEFORE_REQUEST = 2 # Délai entre deux tentatives d'interrogation
    MAX_RESULTS = 20000 # Nombre maximum de résultat pour une recherche
    
    try:
        request_number = 0
        while request_number < MAX_TRY:
            response = requests.get(url)
            request_number += 1
            if response.status_code not in range(200, 299):
                #print(f"\t{url} : Tentative {request_number} - Statut {response.status_code} ({response.reason})")
                time.sleep(DELAY_BEFORE_REQUEST)
            else:
                if request_number != 1:
                    #print(f"\t{url} : Tentative {request_number} - Statut {response.status_code}")
                    pass
                break

        if request_number == MAX_TRY:
            print(f"\t{url} : Abandon après {request_number} tentatives")
            return None

        response = response.json()

        if "count" not in response \
            or "data" not in response \
            or "first" not in response \
            or "last" not in response \
            or "prev" not in response \
            or "next" not in response:
            print(f"\t{url} : Réponse invalide")
            return None

        if response['count'] == 0 or len(response['data']) == 0:
            #print(f"\t{url} : Aucun résultat")
            return None
        
        if response['count'] > MAX_RESULTS:
            return None

        return response

    except Exception as e:
        print(f"{url} : Erreur \n{e}")

# %% [markdown]
# ## Téléchargement des données des stations de mesure
# Nous sommes prêts pour utiliser l'API Hub'Eau Qualité des nappes pour récupérer et consolider la liste des stations de mesure. Nous limiterons ici la récupération de données au code BSS de la station.
#
# Construisons d'abord l'URL de téléchargement des données des stations :

# %%
# URL de base des API Hub'Eau
base = "http://hubeau.eaufrance.fr/api"
# Point d'accès de l'API Hub'Eau Qualité des nappes d'eau
endpoint = "v1/qualite_nappes"
# Opération de téléchargement des données descriptives des stations
operation = "stations"
# Données souhaitées dans la réponse (cf. données disponibles du modèle Station de mesure de la qualité)
fields = [
    "bss_id", # Identifiant d'une station
]
# Paramètres de la recherche
MAX_RESULTS = 20000
parameters = [
    {
        "parameter": "fields",
        "value": ",".join(fields)
    },
    {
        "parameter": "size",
        "value": MAX_RESULTS # Taille maximale d'une page de résultats de recherche
    }, 
]
# Construction de l'URL de téléchargement des données
parameters = "&".join([f"{param['parameter']}={param['value']}" for param in parameters])
url_base = f"{base}/{endpoint}/{operation}?{parameters}"
url_base
# Out:
# 'http://hubeau.eaufrance.fr/api/v1/qualite_nappes/stations?fields=bss_id&size=20000'

# %% [markdown]
# Téléchargeons les données des stations par département et rassemblons les résultats dans une liste d'identifiants :

# %%
stations = []
for departement in departements:
    # Ajout d'un filtre sur les données du département
    code_departement = departement["CdDepartement"]
    url = url_base + f"&num_departement={code_departement}"
    
    # Interrogation Hub'Eau
    response = get_data(url)
    if not response:
        continue

    # Extraction des données dans la réponse de l'API
    stations += response['data']

print(len(stations))
print(stations[0])
# Out:
# 79972
# {'bss_id': 'BSS001SDAA'}

# %% [markdown]
# ## Téléchargement des données des analyses chimiques des nappes d'eau
# Nous allons enfin utiliser la liste des stations et l'API Hub'Eau Qualité des nappes pour récupérer les données des analyses chimiques recherchées. Pour optimiser les échanges, nous interrogerons l'API par bloc de 10 stations. L'enregistrement des données s'effectuera dasn des fichiers csv de 100000 lignes environ.
#
# Construisons d'abord l'URL de téléchargement des données des analyses :

# %%
# URL de base des API Hub'Eau
base = "http://hubeau.eaufrance.fr/api"
# Point d'accès de l'API Hub'Eau Qualité des nappes d'eau
endpoint = "v1/qualite_nappes"
# Opération de téléchargement des données descriptives des analyses chimiques
operation = "analyses"
# Paramètres de la recherche des analyses
MAX_RESULTS = 20000
parameters = [
    {
        "parameter": "date_debut_prelevement",
        "value": "2021-01-01"
    },
    {
        "parameter": "date_fin_prelevement",
        "value": "2022-12-31"
    },
    {
        "parameter": "code_groupe_parametre",
        "value": "95" # Code Sandre du groupe de paramètres Phytosanitaires, https://id.eaufrance.fr/gpr/95
    },
    {
        "parameter": "code_qualification",
        "value": "1" # Code Sandre de la qualification Correcte, https://id.eaufrance.fr/nsa/414#1
    },
    {
        "parameter": "size",
        "value": MAX_RESULTS # Taille maximale d'une page de résultats de recherche
    }, 
]
# Construction de l'URL de téléchargement des données
parameters = "&".join([f"{param['parameter']}={param['value']}" for param in parameters])
url_base = f"{base}/{endpoint}/{operation}?{parameters}"
url_base
# Out:
# 'http://hubeau.eaufrance.fr/api/v1/qualite_nappes/analyses?date_debut_prelevement=2021-01-01&date_fin_prelevement=2022-12-31&code_groupe_parametre=95&code_qualification=1&size=20000'

# %% [markdown]
# Téléchargeons les données des analyses chimiques par station :

# %%
MAX_CSV_SIZE = 100000
STATION_COUNT = 10

analyses = []
index = 0
i = 0
#for station in stations:
for i in range(0, len(stations), STATION_COUNT):
    bss_ids = [station["bss_id"] for station in stations[i:i + STATION_COUNT]]
    bss_ids = ",".join(bss_ids)
    
    i += 1
    if not i % 1000:
        print(f"Traitement de la {i}ème station...")
    
    # Ajout d'un filtre sur les données des stations
    url = url_base + f"&bss_id={bss_ids}"
    #print(url)
    response = get_data(url)
    if not response:
        continue
       
    # Extraction des données dans la réponse de l'API
    analyses += response['data']

    if len(analyses) > MAX_CSV_SIZE:
        # Création d'un DataFrame
        df = pandas.DataFrame(analyses)
        # Enregistrement du DataFrame dans un fichier CSV
        index += 1
        csv_path = os.path.join(download_folder_path, f"ades_analyses_{index}.csv")
        df.to_csv(
            path_or_buf=csv_path,
            sep=';',
            na_rep='',
            float_format=None,
            columns=None,
            header=True,
            index=False,
            index_label=None,
            mode='w',
            encoding=None,
            compression='infer',
            quoting=None,
            quotechar='"',
            line_terminator=None,
            chunksize=None,
            date_format=None,
            doublequote=True,
            escapechar=None,
            decimal='.'
        )
        # Réinitialisation de la liste d'analyses
        analyses = []

if len(analyses):
    # Création d'un DataFrame
    df = pandas.DataFrame(analyses)
    # Enregistrement du DataFrame dans un fichier CSV
    index += 1
    csv_path = os.path.join(download_folder_path, f"ades_analyses_{index}.csv")
    df.to_csv(
        path_or_buf=csv_path,
        sep=';',
        na_rep='',
        float_format=None,
        columns=None,
        header=True,
        index=False,
        index_label=None,
        mode='w',
        encoding=None,
        compression='infer',
        quoting=None,
        quotechar='"',
        line_terminator=None,
        chunksize=None,
        date_format=None,
        doublequote=True,
        escapechar=None,
        decimal='.'
    )
    # Réinitialisation de la liste d'analyses
    analyses = []

df.head()
# Out:
#        bss_id           code_bss  \
# 0  BSS002PMBD  12307X0021/KAOUE3
# 1  BSS002PMBD  12307X0021/KAOUE3
# 2  BSS002PMBD  12307X0021/KAOUE3
# 3  BSS002PMBD  12307X0021/KAOUE3
# 4  BSS002PMBD  12307X0021/KAOUE3
#
#                                              urn_bss precision_coordonnees  \
# 0  http://services.ades.eaufrance.fr/pointeau/BSS...                  None
# 1  http://services.ades.eaufrance.fr/pointeau/BSS...                  None
# 2  http://services.ades.eaufrance.fr/pointeau/BSS...                  None
# 3  http://services.ades.eaufrance.fr/pointeau/BSS...                  None
# 4  http://services.ades.eaufrance.fr/pointeau/BSS...                  None
#
#    longitude   latitude altitude code_insee_actuel nom_commune_actuel  \
# 0  45.219572 -12.761568     21.0             97611          Mamoudzou
# 1  45.219572 -12.761568     21.0             97611          Mamoudzou
# 2  45.219572 -12.761568     21.0             97611          Mamoudzou
# 3  45.219572 -12.761568     21.0             97611          Mamoudzou
# 4  45.219572 -12.761568     21.0             97611          Mamoudzou
#
#   num_departement  ... code_qualification nom_qualification  \
# 0             976  ...                  1          Correcte
# 1             976  ...                  1          Correcte
# 2             976  ...                  1          Correcte
# 3             976  ...                  1          Correcte
# 4             976  ...                  1          Correcte
#
#                   uri_qualification limite_quantification limite_detection  \
# 0  http://id.eaufrance.fr/NSA/414#1                  0.03           0.0100
# 1  http://id.eaufrance.fr/NSA/414#1                  0.03           0.0100
# 2  http://id.eaufrance.fr/NSA/414#1                  0.01           0.0030
# 3  http://id.eaufrance.fr/NSA/414#1                  0.02           0.0070
# 4  http://id.eaufrance.fr/NSA/414#1                  0.05           0.0167
#
#   seuil_saturation incertitude_analytique  \
# 0             None                   25.0
# 1             None                    NaN
# 2             None                   11.5
# 3             None                   15.0
# 4             None                    NaN
#
#                               codes_groupe_parametre  \
# 0  [191, 61, 41, 95, 199, 130, 127, 203, 73, 132,...
# 1  [148, 121, 167, 50, 150, 31, 149, 207, 191, 12...
# 2  [168, 95, 216, 211, 144, 64, 199, 190, 121, 20...
# 3  [50, 192, 73, 191, 96, 199, 200, 190, 203, 126...
# 4  [168, 211, 95, 207, 209, 190, 121, 113, 191, 1...
#
#                                noms_groupe_parametre  \
# 0  [Avis relatif aux limites de quantification de...
# 1  [Substances pertinentes complémentaires pour l...
# 2  [Liste des micropolluants de l'analyse réguliè...
# 3  [Micropolluants organiques, Avis relatif aux l...
# 4  [Liste des micropolluants de l'analyse réguliè...
#
#                                uris_groupe_parametre
# 0  [http://id.eaufrance.fr/GPR/191, http://id.eau...
# 1  [http://id.eaufrance.fr/GPR/148, http://id.eau...
# 2  [http://id.eaufrance.fr/GPR/168, http://id.eau...
# 3  [http://id.eaufrance.fr/GPR/50, http://id.eauf...
# 4  [http://id.eaufrance.fr/GPR/168, http://id.eau...
#
# [5 rows x 72 columns]
